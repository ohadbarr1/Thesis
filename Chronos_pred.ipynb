# %% [markdown]
# <a href="https://colab.research.google.com/github/ohadbarr1/Thesis/blob/main/Chronos_pred.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Installations and initializations

# %% [markdown]
# Install chronos

# %%
pip install git+https://github.com/amazon-science/chronos-forecasting.git
# Out:
# Collecting git+https://github.com/amazon-science/chronos-forecasting.git
#   Cloning https://github.com/amazon-science/chronos-forecasting.git to /tmp/pip-req-build-ntje5icy
#   Running command git clone --filter=blob:none --quiet https://github.com/amazon-science/chronos-forecasting.git /tmp/pip-req-build-ntje5icy
#   Resolved https://github.com/amazon-science/chronos-forecasting.git to commit eb7bdfc047de3e7af972b4ee7cf23a7968b7daa3
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: torch~=2.0 in /usr/local/lib/python3.10/dist-packages (from chronos==1.2.0) (2.4.0+cu121)
# Requirement already satisfied: transformers~=4.30 in /usr/local/lib/python3.10/dist-packages (from chronos==1.2.0) (4.42.4)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.10/dist-packages (from chronos==1.2.0) (0.32.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch~=2.0->chronos==1.2.0) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch~=2.0->chronos==1.2.0) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch~=2.0->chronos==1.2.0) (1.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch~=2.0->chronos==1.2.0) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch~=2.0->chronos==1.2.0) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch~=2.0->chronos==1.2.0) (2024.6.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers~=4.30->chronos==1.2.0) (0.23.5)
# Requirement already satisfied: numpy<2.0,>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers~=4.30->chronos==1.2.0) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers~=4.30->chronos==1.2.0) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers~=4.30->chronos==1.2.0) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers~=4.30->chronos==1.2.0) (2024.5.15)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers~=4.30->chronos==1.2.0) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers~=4.30->chronos==1.2.0) (0.4.4)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers~=4.30->chronos==1.2.0) (0.19.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers~=4.30->chronos==1.2.0) (4.66.5)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate->chronos==1.2.0) (5.9.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch~=2.0->chronos==1.2.0) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers~=4.30->chronos==1.2.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers~=4.30->chronos==1.2.0) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers~=4.30->chronos==1.2.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers~=4.30->chronos==1.2.0) (2024.7.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch~=2.0->chronos==1.2.0) (1.3.0)
# Building wheels for collected packages: chronos
#   Building wheel for chronos (pyproject.toml) ... done
#   Created wheel for chronos: filename=chronos-1.2.0-py3-none-any.whl size=13908 sha256=a78965f69811f3fc0dff9641d8179a5704ce328475bc6076276667240cb452e8
#   Stored in directory: /tmp/pip-ephem-wheel-cache-9dwyvjqd/wheels/bf/c1/65/08857e57345ef1b34ba0edb4791f1b2594943e82f34e93a4ab
# Successfully built chronos
# Installing collected packages: chronos
# Successfully installed chronos-1.2.0

# %% [markdown]
# ## **Import libraries**

# %%
# Import relevant libraries
import pandas as pd
import numpy as np
from google.colab import files
from datetime import timedelta

# Data preprocessing
from sklearn.preprocessing import MinMaxScaler

# Gather financial data
import yfinance as yf

# Plots
import matplotlib.pyplot as plt
import plotly.graph_objects as go

# Models
import torch
from sklearn.model_selection import train_test_split
from chronos import ChronosPipeline

# %% [markdown]
# ## Initializing pipeline

# %%
# Use the Chronos-t5-base model, 200m parameters
pipeline = ChronosPipeline.from_pretrained(
  "amazon/chronos-t5-base",
  device_map="cuda",
  torch_dtype=torch.bfloat16,
)
# Out:
# config.json:   0%|          | 0.00/1.12k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/806M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/142 [00:00<?, ?B/s]

# %% [markdown]
# ### Gather VIX Data

# %%
# Data fetching and preprocessing
tickers = ['^VIX9D', '^VIX', '^VIX3M', '^VIX6M']
data = yf.download(tickers, start="2011-01-03")['Close']
# Reordering columns and renaming them according to your format
data = data[['^VIX', '^VIX3M', '^VIX6M', '^VIX9D']]
data.columns = ['VIX', 'VIX3M', 'VIX6M', 'VIX9D']
# Resetting index to make 'Date' a column
data.reset_index(inplace=True)

data
# Out:
# [*********************100%***********************]  4 of 4 completed
#                           Date        VIX      VIX3M      VIX6M      VIX9D
# 0    2011-01-03 00:00:00+00:00  17.610001  20.620001  23.400000  16.040001
# 1    2011-01-04 00:00:00+00:00  17.379999  20.610001  23.190001  16.059999
# 2    2011-01-05 00:00:00+00:00  17.020000  20.049999  22.780001  15.570000
# 3    2011-01-06 00:00:00+00:00  17.400000  20.350000  22.870001  15.710000
# 4    2011-01-07 00:00:00+00:00  17.139999  20.290001  22.920000  15.010000
# ...                        ...        ...        ...        ...        ...
# 3433 2024-08-26 00:00:00+00:00  16.150000  18.250000  19.360001  14.870000
# 3434 2024-08-27 00:00:00+00:00  15.430000  17.730000  19.000000  14.170000
# 3435 2024-08-28 00:00:00+00:00  17.110001  18.900000  19.830000  16.639999
# 3436 2024-08-29 00:00:00+00:00  15.650000  18.000000  19.309999  13.730000
# 3437 2024-08-30 00:00:00+00:00  15.550000        NaN        NaN        NaN
#
# [3438 rows x 5 columns]

# %%
VIX9D = data[['Date','VIX9D']]
VIX = data[['Date','VIX']]
VIX3M = data[['Date','VIX3M']]
VIX6M = data[['Date','VIX6M']]

# %% [markdown]
# VIX Data

# %%
# Avoid SettingWithCopyWarning by using .loc
VIX.loc[:, 'Date'] = pd.to_datetime(VIX['Date'])

# Initialize a DataFrame to store results
results = pd.DataFrame(columns=['Date', 'Actual', 'Forecast'])

# Number of days in three days (approx.)
days = timedelta(days=2)

# Loop over the DataFrame
for i in range(872, len(VIX),2):
    # Define the current date
    current_date = VIX['Date'].iloc[i]
    end_date = current_date + days

    # Use all data up to the current date as context
    context_data = VIX[VIX['Date'] <= current_date]

    # Filter data for the next three days (actual future values)
    actual_next_day = VIX[(VIX['Date'] > current_date) & (VIX['Date'] <= end_date)]

    # Convert the entire context up to the current date to a tensor
    context = torch.tensor(context_data["VIX"].values, dtype=torch.float32).unsqueeze(0)

    # Initialize a list to store forecasts
    forecasts = []

    # Make a prediction for the next three days
    prediction_length = min(len(actual_next_day), 1)  # Predicting 2 days or fewer if the actual data is less
    if prediction_length > 0:  # Ensure there's something to predict
        forecast = pipeline.predict(context, prediction_length)
        if forecast is not None and len(forecast) > 0:
            forecast = forecast.squeeze().cpu().numpy()

            # Ensure forecast is 1-dimensional
            if forecast.ndim > 1:
                forecast = forecast.flatten()

            # Store the forecast
            forecasts.append(forecast)

    # Proceed only if we have forecasts
    if forecasts:
        # Ensure the lengths of actual and forecasts match
        forecast_dates = actual_next_day['Date'].values
        aligned_length = min(len(forecast_dates), len(forecasts[0]))
        forecast_dates = forecast_dates[:aligned_length]
        actual_values = actual_next_day['VIX'].values[:aligned_length]

        # Truncate forecasts to the aligned length
        forecasts = [forecast[:aligned_length] for forecast in forecasts]

        # Calculate the average of the 5 forecasts
        forecast_avg = np.mean(forecasts, axis=0)

        # Store the results in the DataFrame
        result_df = pd.DataFrame({
            'Date': forecast_dates,
            'Actual': actual_values,
            'Forecast_Avg': forecasts[0]
        })

        # Avoid concatenating empty dataframes
        if not result_df.empty:
            # Append to the main results DataFrame
            results = pd.concat([results, result_df], ignore_index=True)

# Reset index of the final DataFrame
results.reset_index(drop=True, inplace=True)

# Create the interactive plot
import plotly.graph_objects as go

# Create the plot
fig = go.Figure()

# Add the actual values line
fig.add_trace(go.Scatter(
    x=results['Date'],
    y=results['Actual'],
    mode='lines',
    name='Actual Values',
    line=dict(color='blue')
))

# Add the averaged forecast values line
fig.add_trace(go.Scatter(
    x=results['Date'],
    y=results['Forecast_Avg'],
    mode='lines',
    name='Forecasted Values (Avg)',
    line=dict(color='red')
))

# Update layout
fig.update_layout(
    title="Forecasted vs Actual VIX Values (Next-Day Predictions)",
    xaxis_title="Date",
    yaxis_title="VIX Value",
    legend_title="Legend",
    hovermode="x unified"
)

# Show the interactive plot
fig.show()

# prompt: convert to csv and download results_df and call it "VIX.csv"

# Assuming 'results' is your DataFrame
results.to_csv('Chronos_VIX_pred.csv', index=False)
files.download('Chronos_VIX_pred.csv')
# Out:
# <ipython-input-28-603cf525c8ec>:66: FutureWarning:
#
# The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.

# %% [markdown]
# VIX 9D

# %%
# Avoid SettingWithCopyWarning by using .loc
VIX9D.loc[:, 'Date'] = pd.to_datetime(VIX9D['Date'])

# Initialize a DataFrame to store results
results = pd.DataFrame(columns=['Date', 'Actual', 'Forecast'])

# Number of days in three days (approx.)
days = timedelta(days=2)

# Loop over the DataFrame
for i in range(872, len(VIX9D), 2):
    # Define the current date
    current_date = VIX9D['Date'].iloc[i]
    end_date = current_date + days

    # Use all data up to the current date as context
    context_data = VIX9D[VIX9D['Date'] <= current_date]

    # Filter data for the next three days (actual future values)
    actual_next_day = VIX9D[(VIX9D['Date'] > current_date) & (VIX9D['Date'] <= end_date)]

    # Convert the entire context up to the current date to a tensor
    context = torch.tensor(context_data["VIX9D"].values, dtype=torch.float32).unsqueeze(0)

    # Initialize a list to store forecasts
    forecasts = []

    # Make a prediction for the next three days
    prediction_length = min(len(actual_next_day), 1)  # Predicting 1 day or fewer if the actual data is less
    if prediction_length > 0:  # Ensure there's something to predict
        forecast = pipeline.predict(context, prediction_length)
        if forecast is not None and len(forecast) > 0:
            forecast = forecast.squeeze().cpu().numpy()

            # Ensure forecast is 1-dimensional
            if forecast.ndim > 1:
                forecast = forecast.flatten()

            # Store the forecast
            forecasts.append(forecast)

    # Proceed only if we have forecasts
    if forecasts:
        # Ensure the lengths of actual and forecasts match
        forecast_dates = actual_next_day['Date'].values
        aligned_length = min(len(forecast_dates), len(forecasts[0]))
        forecast_dates = forecast_dates[:aligned_length]
        actual_values = actual_next_day['VIX9D'].values[:aligned_length]

        # Truncate forecasts to the aligned length
        forecasts = [forecast[:aligned_length] for forecast in forecasts]

        # Calculate the average of the 5 forecasts
        forecast_avg = np.mean(forecasts, axis=0)

        # Store the results in the DataFrame
        result_df = pd.DataFrame({
            'Date': forecast_dates,
            'Actual': actual_values,
            'Forecast_Avg': forecasts[0]
        })

        # Avoid concatenating empty dataframes
        if not result_df.empty:
            # Append to the main results DataFrame
            results = pd.concat([results, result_df], ignore_index=True)

# Reset index of the final DataFrame
results.reset_index(drop=True, inplace=True)

# Create the interactive plot
import plotly.graph_objects as go

# Create the plot
fig = go.Figure()

# Add the actual values line
fig.add_trace(go.Scatter(
    x=results['Date'],
    y=results['Actual'],
    mode='lines',
    name='Actual Values',
    line=dict(color='blue')
))

# Add the averaged forecast values line
fig.add_trace(go.Scatter(
    x=results['Date'],
    y=results['Forecast_Avg'],
    mode='lines',
    name='Forecasted Values (Avg)',
    line=dict(color='red')
))

# Update layout
fig.update_layout(
    title="Forecasted vs Actual VIX9D Values (Next-Day Predictions)",
    xaxis_title="Date",
    yaxis_title="VIX9D Value",
    legend_title="Legend",
    hovermode="x unified"
)

# Show the interactive plot
fig.show()


# Assuming 'results' is your DataFrame
results.to_csv('Chronos_VIX9D_pred.csv', index=False)
files.download('Chronos_VIX9D_pred.csv')
# Out:
# <ipython-input-10-a281b9667b2e>:66: FutureWarning:
#
# The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#
# /usr/local/lib/python3.10/dist-packages/_plotly_utils/basevalidators.py:105: FutureWarning:
#
# The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="696b3be5-ea82-423a-ac6f-e6ce3bf007c5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("696b3be5-ea82-423a-ac6f-e6ce3bf007c5")) {                    Plotly.newPlot(                        "696b3be5-ea82-423a-ac6f-e6ce3bf007c5",                        [{"line":{"color":"blue"},"mode":"lines","name":"Actual Values","x":["2014-06-24T00:00:00","2014-06-25T00:00:00","2014-06-26T00:00:00","2014-06-27T00:00:00","2014-07-01T00:00:00","2014-07-02T00:00:00","2014-07-03T00:00:00","2014-07-08T00:00:00","2014-07-09T00:00:00","2014-07-10T00:00:00","2014-07-11T00:00:00","2014-07-15T00:00:00","2014-07-16T00:00:00","2014-07-17T00:00:00","2014-07-18T00:00:00","2014-07-22T00:00:00","2014-07-23T00:00:00","2014-07-24T00:00:00","2014-07-25T00:00:00","2014-07-29T00:00:00","2014-07-30T00:00:00","2014-07-31T00:00:00","2014-08-01T00:00:00","2014-08-05T00:00:00","2014-08-06T00:00:00","2014-08-07T00:00:00","2014-08-08T00:00:00","2014-08-12T00:00:00","2014-08-13T00:00:00","2014-08-14T00:00:00","2014-08-15T00:00:00","2014-08-19T00:00:00","2014-08-20T00:00:00","2014-08-21T00:00:00","2014-08-22T00:00:00","2014-08-26T00:00:00","2014-08-27T00:00:00","2014-08-28T00:00:00","2014-08-29T00:00:00","2014-09-03T00:00:00","2014-09-04T00:00:00","2014-09-05T00:00:00","2014-09-09T00:00:00","2014-09-10T00:00:00","2014-09-11T00:00:00","2014-09-12T00:00:00","2014-09-16T00:00:00","2014-09-17T00:00:00","2014-09-18T00:00:00","2014-09-19T00:00:00","2014-09-23T00:00:00","2014-09-24T00:00:00","2014-09-25T00:00:00","2014-09-26T00:00:00","2014-09-30T00:00:00","2014-10-01T00:00:00","2014-10-02T00:00:00","2014-10-03T00:00:00","2014-10-07T00:00:00","2014-10-08T00:00:00","2014-10-09T00:00:00","2014-10-10T00:00:00","2014-10-14T00:00:00","2014-10-15T00:00:00","2014-10-16T00:00:00","2014-10-17T00:00:00","2014-10-21T00:00:00","2014-10-22T00:00:00","2014-10-23T00:00:00","2014-10-24T00:00:00","2014-10-28T00:00:00","2014-10-29T00:00:00","2014-10-30T00:00:00","2014-10-31T00:00:00","2014-11-04T00:00:00","2014-11-05T00:00:00","2014-11-06T00:00:00","2014-11-07T00:00:00","2014-11-11T00:00:00","2014-11-12T00:00:00","2014-11-13T00:00:00","2014-11-14T00:00:00","2014-11-18T00:00:00","2014-11-19T00:00:00","2014-11-20T00:00:00","2014-11-21T00:00:00","2014-11-25T00:00:00","2014-11-26T00:00:00","2014-12-02T00:00:00","2014-12-03T00:00:00","2014-12-04T00:00:00","2014-12-05T00:00:00","2014-12-09T00:00:00","2014-12-10T00:00:00","2014-12-11T00:00:00","2014-12-12T00:00:00","2014-12-16T00:00:00","2014-12-17T00:00:00","2014-12-18T00:00:00","2014-12-19T00:00:00","2014-12-23T00:00:00","2014-12-24T00:00:00","2014-12-30T00:00:00","2014-12-31T00:00:00","2015-01-06T00:00:00","2015-01-07T00:00:00","2015-01-08T00:00:00","2015-01-09T00:00:00","2015-01-13T00:00:00","2015-01-14T00:00:00","2015-01-15T00:00:00","2015-01-16T00:00:00","2015-01-21T00:00:00","2015-01-22T00:00:00","2015-01-23T00:00:00","2015-01-27T00:00:00","2015-01-28T00:00:00","2015-01-29T00:00:00","2015-01-30T00:00:00","2015-02-03T00:00:00","2015-02-04T00:00:00","2015-02-05T00:00:00","2015-02-06T00:00:00","2015-02-10T00:00:00","2015-02-11T00:00:00","2015-02-12T00:00:00","2015-02-13T00:00:00","2015-02-18T00:00:00","2015-02-19T00:00:00","2015-02-20T00:00:00","2015-02-24T00:00:00","2015-02-25T00:00:00","2015-02-26T00:00:00","2015-02-27T00:00:00","2015-03-03T00:00:00","2015-03-04T00:00:00","2015-03-05T00:00:00","2015-03-06T00:00:00","2015-03-10T00:00:00","2015-03-11T00:00:00","2015-03-12T00:00:00","2015-03-13T00:00:00","2015-03-17T00:00:00","2015-03-18T00:00:00","2015-03-19T00:00:00","2015-03-20T00:00:00","2015-03-24T00:00:00","2015-03-25T00:00:00","2015-03-26T00:00:00","2015-03-27T00:00:00","2015-03-31T00:00:00","2015-04-01T00:00:00","2015-04-02T00:00:00","2 ...

# %% [markdown]
# VIX3M

# %%
# Avoid SettingWithCopyWarning by using .loc
VIX3M.loc[:, 'Date'] = pd.to_datetime(VIX3M['Date'])

# Initialize a DataFrame to store results
results = pd.DataFrame(columns=['Date', 'Actual', 'Forecast'])

# Number of days in three days (approx.)
day = timedelta(days=1)

# Loop over the DataFrame
for i in range(872, len(VIX3M), 2):
    # Define the current date
    current_date = VIX3M['Date'].iloc[i]
    end_date = current_date + day

    # Use all data up to the current date as context
    context_data = VIX3M[VIX3M['Date'] <= current_date]

    # Filter data for the next three days (actual future values)
    actual_next_day = VIX3M[(VIX3M['Date'] > current_date) & (VIX3M['Date'] <= end_date)]

    # Convert the entire context up to the current date to a tensor
    context = torch.tensor(context_data["VIX3M"].values, dtype=torch.float32).unsqueeze(0)

    # Initialize a list to store forecasts
    forecasts = []

    # Make a prediction for the next three days
    prediction_length = min(len(actual_next_day), 1)  # Predicting 3 days or fewer if the actual data is less
    if prediction_length > 0:  # Ensure there's something to predict
        forecast = pipeline.predict(context, prediction_length)
        if forecast is not None and len(forecast) > 0:
            forecast = forecast.squeeze().cpu().numpy()

            # Ensure forecast is 1-dimensional
            if forecast.ndim > 1:
                forecast = forecast.flatten()

            # Store the forecast
            forecasts.append(forecast)

    # Proceed only if we have forecasts
    if forecasts:
        # Ensure the lengths of actual and forecasts match
        forecast_dates = actual_next_day['Date'].values
        aligned_length = min(len(forecast_dates), len(forecasts[0]))
        forecast_dates = forecast_dates[:aligned_length]
        actual_values = actual_next_day['VIX3M'].values[:aligned_length]

        # Truncate forecasts to the aligned length
        forecasts = [forecast[:aligned_length] for forecast in forecasts]

        # Calculate the average of the 5 forecasts
        forecast_avg = np.mean(forecasts, axis=0)

        # Store the results in the DataFrame
        result_df = pd.DataFrame({
            'Date': forecast_dates,
            'Actual': actual_values,
            'Forecast_Avg': forecasts[0]
        })

        # Avoid concatenating empty dataframes
        if not result_df.empty:
            # Append to the main results DataFrame
            results = pd.concat([results, result_df], ignore_index=True)

# Reset index of the final DataFrame
results.reset_index(drop=True, inplace=True)

# Create the interactive plot
import plotly.graph_objects as go

# Create the plot
fig = go.Figure()

# Add the actual values line
fig.add_trace(go.Scatter(
    x=results['Date'],
    y=results['Actual'],
    mode='lines',
    name='Actual Values',
    line=dict(color='blue')
))

# Add the averaged forecast values line
fig.add_trace(go.Scatter(
    x=results['Date'],
    y=results['Forecast_Avg'],
    mode='lines',
    name='Forecasted Values (Avg)',
    line=dict(color='red')
))

# Update layout
fig.update_layout(
    title="Forecasted vs Actual VIX3M Values (Next-Day Predictions)",
    xaxis_title="Date",
    yaxis_title="VIX3M Value",
    legend_title="Legend",
    hovermode="x unified"
)

# Show the interactive plot
fig.show()


# Assuming 'results' is your DataFrame
results.to_csv('Chronos_VIX3M_pred.csv', index=False)
files.download('Chronos_VIX3M_pred.csv')
# Out:
# <ipython-input-11-784ea701a69c>:66: FutureWarning:
#
# The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#
# /usr/local/lib/python3.10/dist-packages/_plotly_utils/basevalidators.py:105: FutureWarning:
#
# The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="b05bd8c2-8c2f-42b9-b5ab-7b8f878bb682" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b05bd8c2-8c2f-42b9-b5ab-7b8f878bb682")) {                    Plotly.newPlot(                        "b05bd8c2-8c2f-42b9-b5ab-7b8f878bb682",                        [{"line":{"color":"blue"},"mode":"lines","name":"Actual Values","x":["2014-06-24T00:00:00","2014-06-25T00:00:00","2014-06-26T00:00:00","2014-06-27T00:00:00","2014-07-01T00:00:00","2014-07-02T00:00:00","2014-07-03T00:00:00","2014-07-08T00:00:00","2014-07-09T00:00:00","2014-07-10T00:00:00","2014-07-11T00:00:00","2014-07-15T00:00:00","2014-07-16T00:00:00","2014-07-17T00:00:00","2014-07-18T00:00:00","2014-07-22T00:00:00","2014-07-23T00:00:00","2014-07-24T00:00:00","2014-07-25T00:00:00","2014-07-29T00:00:00","2014-07-30T00:00:00","2014-07-31T00:00:00","2014-08-01T00:00:00","2014-08-05T00:00:00","2014-08-06T00:00:00","2014-08-07T00:00:00","2014-08-08T00:00:00","2014-08-12T00:00:00","2014-08-13T00:00:00","2014-08-14T00:00:00","2014-08-15T00:00:00","2014-08-19T00:00:00","2014-08-20T00:00:00","2014-08-21T00:00:00","2014-08-22T00:00:00","2014-08-26T00:00:00","2014-08-27T00:00:00","2014-08-28T00:00:00","2014-08-29T00:00:00","2014-09-03T00:00:00","2014-09-04T00:00:00","2014-09-05T00:00:00","2014-09-09T00:00:00","2014-09-10T00:00:00","2014-09-11T00:00:00","2014-09-12T00:00:00","2014-09-16T00:00:00","2014-09-17T00:00:00","2014-09-18T00:00:00","2014-09-19T00:00:00","2014-09-23T00:00:00","2014-09-24T00:00:00","2014-09-25T00:00:00","2014-09-26T00:00:00","2014-09-30T00:00:00","2014-10-01T00:00:00","2014-10-02T00:00:00","2014-10-03T00:00:00","2014-10-07T00:00:00","2014-10-08T00:00:00","2014-10-09T00:00:00","2014-10-10T00:00:00","2014-10-14T00:00:00","2014-10-15T00:00:00","2014-10-16T00:00:00","2014-10-17T00:00:00","2014-10-21T00:00:00","2014-10-22T00:00:00","2014-10-23T00:00:00","2014-10-24T00:00:00","2014-10-28T00:00:00","2014-10-29T00:00:00","2014-10-30T00:00:00","2014-10-31T00:00:00","2014-11-04T00:00:00","2014-11-05T00:00:00","2014-11-06T00:00:00","2014-11-07T00:00:00","2014-11-11T00:00:00","2014-11-12T00:00:00","2014-11-13T00:00:00","2014-11-14T00:00:00","2014-11-18T00:00:00","2014-11-19T00:00:00","2014-11-20T00:00:00","2014-11-21T00:00:00","2014-11-25T00:00:00","2014-11-26T00:00:00","2014-12-02T00:00:00","2014-12-03T00:00:00","2014-12-04T00:00:00","2014-12-05T00:00:00","2014-12-09T00:00:00","2014-12-10T00:00:00","2014-12-11T00:00:00","2014-12-12T00:00:00","2014-12-16T00:00:00","2014-12-17T00:00:00","2014-12-18T00:00:00","2014-12-19T00:00:00","2014-12-23T00:00:00","2014-12-24T00:00:00","2014-12-30T00:00:00","2014-12-31T00:00:00","2015-01-06T00:00:00","2015-01-07T00:00:00","2015-01-08T00:00:00","2015-01-09T00:00:00","2015-01-13T00:00:00","2015-01-14T00:00:00","2015-01-15T00:00:00","2015-01-16T00:00:00","2015-01-21T00:00:00","2015-01-22T00:00:00","2015-01-23T00:00:00","2015-01-27T00:00:00","2015-01-28T00:00:00","2015-01-29T00:00:00","2015-01-30T00:00:00","2015-02-03T00:00:00","2015-02-04T00:00:00","2015-02-05T00:00:00","2015-02-06T00:00:00","2015-02-10T00:00:00","2015-02-11T00:00:00","2015-02-12T00:00:00","2015-02-13T00:00:00","2015-02-18T00:00:00","2015-02-19T00:00:00","2015-02-20T00:00:00","2015-02-24T00:00:00","2015-02-25T00:00:00","2015-02-26T00:00:00","2015-02-27T00:00:00","2015-03-03T00:00:00","2015-03-04T00:00:00","2015-03-05T00:00:00","2015-03-06T00:00:00","2015-03-10T00:00:00","2015-03-11T00:00:00","2015-03-12T00:00:00","2015-03-13T00:00:00","2015-03-17T00:00:00","2015-03-18T00:00:00","2015-03-19T00:00:00","2015-03-20T00:00:00","2015-03-24T00:00:00","2015-03-25T00:00:00","2015-03-26T00:00:00","2015-03-27T00:00:00","2015-03-31T00:00:00","2015-04-01T00:00:00","2015-04-02T00:00:00","2 ...

# %% [markdown]
# VIX6M

# %%
# Avoid SettingWithCopyWarning by using .loc
VIX6M.loc[:, 'Date'] = pd.to_datetime(VIX6M['Date'])

# Initialize a DataFrame to store results
results = pd.DataFrame(columns=['Date', 'Actual', 'Forecast'])

# Number of days in two days (approx.)
days = timedelta(days=2)

# Loop over the DataFrame
for i in range(872, len(VIX6M), 2):
    # Define the current date
    current_date = VIX6M['Date'].iloc[i]
    end_date = current_date + days

    # Use all data up to the current date as context
    context_data = VIX6M[VIX6M['Date'] <= current_date]

    # Filter data for the next three days (actual future values)
    actual_next_day = VIX6M[(VIX6M['Date'] > current_date) & (VIX6M['Date'] <= end_date)]

    # Convert the entire context up to the current date to a tensor
    context = torch.tensor(context_data["VIX6M"].values, dtype=torch.float32).unsqueeze(0)

    # Initialize a list to store forecasts
    forecasts = []

    # Make a prediction for the next three days
    prediction_length = min(len(actual_next_day), 1)  # Predicting 3 days or fewer if the actual data is less
    if prediction_length > 0:  # Ensure there's something to predict
        forecast = pipeline.predict(context, prediction_length)
        if forecast is not None and len(forecast) > 0:
            forecast = forecast.squeeze().cpu().numpy()

            # Ensure forecast is 1-dimensional
            if forecast.ndim > 1:
                forecast = forecast.flatten()

            # Store the forecast
            forecasts.append(forecast)

    # Proceed only if we have forecasts
    if forecasts:
        # Ensure the lengths of actual and forecasts match
        forecast_dates = actual_next_day['Date'].values
        aligned_length = min(len(forecast_dates), len(forecasts[0]))
        forecast_dates = forecast_dates[:aligned_length]
        actual_values = actual_next_day['VIX6M'].values[:aligned_length]

        # Truncate forecasts to the aligned length
        forecasts = [forecast[:aligned_length] for forecast in forecasts]

        # Calculate the average of the 5 forecasts
        forecast_avg = np.mean(forecasts, axis=0)

        # Store the results in the DataFrame
        result_df = pd.DataFrame({
            'Date': forecast_dates,
            'Actual': actual_values,
            'Forecast_Avg': forecasts[0]
        })

        # Avoid concatenating empty dataframes
        if not result_df.empty:
            # Append to the main results DataFrame
            results = pd.concat([results, result_df], ignore_index=True)

# Reset index of the final DataFrame
results.reset_index(drop=True, inplace=True)

# Create the interactive plot
import plotly.graph_objects as go

# Create the plot
fig = go.Figure()

# Add the actual values line
fig.add_trace(go.Scatter(
    x=results['Date'],
    y=results['Actual'],
    mode='lines',
    name='Actual Values',
    line=dict(color='blue')
))

# Add the averaged forecast values line
fig.add_trace(go.Scatter(
    x=results['Date'],
    y=results['Forecast_Avg'],
    mode='lines',
    name='Forecasted Values (Avg)',
    line=dict(color='red')
))

# Update layout
fig.update_layout(
    title="Forecasted vs Actual VIX6M Values (Next-Day Predictions)",
    xaxis_title="Date",
    yaxis_title="VIX6M Value",
    legend_title="Legend",
    hovermode="x unified"
)

# Show the interactive plot
fig.show()


# Assuming 'results' is your DataFrame
results.to_csv('Chronos_VIX6M_pred.csv', index=False)
files.download('Chronos_VIX6M_pred.csv')
# Out:
# <ipython-input-13-69cd3347fdac>:66: FutureWarning:
#
# The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#
# /usr/local/lib/python3.10/dist-packages/_plotly_utils/basevalidators.py:105: FutureWarning:
#
# The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="d00d600b-d004-4186-bdd8-9fae0073f2d6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d00d600b-d004-4186-bdd8-9fae0073f2d6")) {                    Plotly.newPlot(                        "d00d600b-d004-4186-bdd8-9fae0073f2d6",                        [{"line":{"color":"blue"},"mode":"lines","name":"Actual Values","x":["2014-06-24T00:00:00","2014-06-25T00:00:00","2014-06-26T00:00:00","2014-06-27T00:00:00","2014-07-01T00:00:00","2014-07-02T00:00:00","2014-07-03T00:00:00","2014-07-08T00:00:00","2014-07-09T00:00:00","2014-07-10T00:00:00","2014-07-11T00:00:00","2014-07-15T00:00:00","2014-07-16T00:00:00","2014-07-17T00:00:00","2014-07-18T00:00:00","2014-07-22T00:00:00","2014-07-23T00:00:00","2014-07-24T00:00:00","2014-07-25T00:00:00","2014-07-29T00:00:00","2014-07-30T00:00:00","2014-07-31T00:00:00","2014-08-01T00:00:00","2014-08-05T00:00:00","2014-08-06T00:00:00","2014-08-07T00:00:00","2014-08-08T00:00:00","2014-08-12T00:00:00","2014-08-13T00:00:00","2014-08-14T00:00:00","2014-08-15T00:00:00","2014-08-19T00:00:00","2014-08-20T00:00:00","2014-08-21T00:00:00","2014-08-22T00:00:00","2014-08-26T00:00:00","2014-08-27T00:00:00","2014-08-28T00:00:00","2014-08-29T00:00:00","2014-09-03T00:00:00","2014-09-04T00:00:00","2014-09-05T00:00:00","2014-09-09T00:00:00","2014-09-10T00:00:00","2014-09-11T00:00:00","2014-09-12T00:00:00","2014-09-16T00:00:00","2014-09-17T00:00:00","2014-09-18T00:00:00","2014-09-19T00:00:00","2014-09-23T00:00:00","2014-09-24T00:00:00","2014-09-25T00:00:00","2014-09-26T00:00:00","2014-09-30T00:00:00","2014-10-01T00:00:00","2014-10-02T00:00:00","2014-10-03T00:00:00","2014-10-07T00:00:00","2014-10-08T00:00:00","2014-10-09T00:00:00","2014-10-10T00:00:00","2014-10-14T00:00:00","2014-10-15T00:00:00","2014-10-16T00:00:00","2014-10-17T00:00:00","2014-10-21T00:00:00","2014-10-22T00:00:00","2014-10-23T00:00:00","2014-10-24T00:00:00","2014-10-28T00:00:00","2014-10-29T00:00:00","2014-10-30T00:00:00","2014-10-31T00:00:00","2014-11-04T00:00:00","2014-11-05T00:00:00","2014-11-06T00:00:00","2014-11-07T00:00:00","2014-11-11T00:00:00","2014-11-12T00:00:00","2014-11-13T00:00:00","2014-11-14T00:00:00","2014-11-18T00:00:00","2014-11-19T00:00:00","2014-11-20T00:00:00","2014-11-21T00:00:00","2014-11-25T00:00:00","2014-11-26T00:00:00","2014-12-02T00:00:00","2014-12-03T00:00:00","2014-12-04T00:00:00","2014-12-05T00:00:00","2014-12-09T00:00:00","2014-12-10T00:00:00","2014-12-11T00:00:00","2014-12-12T00:00:00","2014-12-16T00:00:00","2014-12-17T00:00:00","2014-12-18T00:00:00","2014-12-19T00:00:00","2014-12-23T00:00:00","2014-12-24T00:00:00","2014-12-30T00:00:00","2014-12-31T00:00:00","2015-01-06T00:00:00","2015-01-07T00:00:00","2015-01-08T00:00:00","2015-01-09T00:00:00","2015-01-13T00:00:00","2015-01-14T00:00:00","2015-01-15T00:00:00","2015-01-16T00:00:00","2015-01-21T00:00:00","2015-01-22T00:00:00","2015-01-23T00:00:00","2015-01-27T00:00:00","2015-01-28T00:00:00","2015-01-29T00:00:00","2015-01-30T00:00:00","2015-02-03T00:00:00","2015-02-04T00:00:00","2015-02-05T00:00:00","2015-02-06T00:00:00","2015-02-10T00:00:00","2015-02-11T00:00:00","2015-02-12T00:00:00","2015-02-13T00:00:00","2015-02-18T00:00:00","2015-02-19T00:00:00","2015-02-20T00:00:00","2015-02-24T00:00:00","2015-02-25T00:00:00","2015-02-26T00:00:00","2015-02-27T00:00:00","2015-03-03T00:00:00","2015-03-04T00:00:00","2015-03-05T00:00:00","2015-03-06T00:00:00","2015-03-10T00:00:00","2015-03-11T00:00:00","2015-03-12T00:00:00","2015-03-13T00:00:00","2015-03-17T00:00:00","2015-03-18T00:00:00","2015-03-19T00:00:00","2015-03-20T00:00:00","2015-03-24T00:00:00","2015-03-25T00:00:00","2015-03-26T00:00:00","2015-03-27T00:00:00","2015-03-31T00:00:00","2015-04-01T00:00:00","2015-04-02T00:00:00","2 ...

# %% [markdown]
# ### Signal Predictions

# %%
def classify_row(row):
    if row['VIX9D'] < row['VIX'] and row['VIX'] < row['VIX3M']:
        if row['VIX9D'] < 9:
            return 0
        else:
            return 1
    elif row['VIX9D'] - row['VIX'] > 1 and row['VIX9D'] - row['VIX3M'] > 1 and row['VIX9D'] - row['VIX6M'] > 1 :
        if row['VIX9D'] > 40:
            return 1
        else:
            return -1
    elif row['VIX9D'] - row['VIX'] > 1 and row['VIX9D'] < row['VIX3M']:
        return 0
    else:
        return 1

data["Signal"] = data.apply(classify_row, axis=1)
Signal = data[["Date", "Signal"]]

# %%
# Fill in missing dates in the Signal DataFrame
all_dates = pd.date_range(start=Signal['Date'].min(), end=Signal['Date'].max(), freq='D')
Signal = Signal.set_index('Date').reindex(all_dates).reset_index().rename(columns={'index': 'Date'})

# Ensure 'Date' column exists after reindexing
print("After reindexing Signal:", Signal.columns)

# Initialize the results DataFrame
results = pd.DataFrame(columns=['Date', 'Actual', 'Forecast_signal'])

# Number of days in one day
day = timedelta(days=1)

# Loop over the DataFrame
for i in range(872, len(Signal)):
    current_date = Signal['Date'].iloc[i]
    end_date = current_date + day

    context_data = Signal[Signal['Date'] <= current_date]
    actual_next_day = Signal[(Signal['Date'] > current_date) & (Signal['Date'] <= end_date)]

    # Convert the entire context up to the current date to a tensor
    context = torch.tensor(context_data["Signal"].values, dtype=torch.float32).unsqueeze(0)

    forecasts = []
    prediction_length = min(len(actual_next_day), 1)  # Predicting 1 day

    if prediction_length > 0:
        forecast = pipeline.predict(context, prediction_length)
        if forecast is not None and len(forecast) > 0:
            forecast = forecast.squeeze().cpu().numpy()
            if forecast.ndim > 1:
                forecast = forecast.flatten()
            forecasts.append(forecast)

    if forecasts:
        forecast_dates = actual_next_day['Date'].values
        aligned_length = min(len(forecast_dates), len(forecasts[0]))

        if aligned_length > 0:
            forecast_dates = forecast_dates[:aligned_length]
            actual_values = actual_next_day['Signal'].values[:aligned_length]
            forecasts = [forecast[:aligned_length] for forecast in forecasts]

            result_df = pd.DataFrame({
                'Date': forecast_dates,
                'Actual': actual_values,
                'Forecast_signal': forecasts[0]
            })

            # Debugging: Check the result_df before concatenation
            print(f"Result DataFrame at iteration {i}:")
            print(result_df.head())

            if not result_df.empty and result_df.notna().all().all():
                results = pd.concat([results, result_df], ignore_index=True)

# Reset index of the final DataFrame
results.reset_index(drop=True, inplace=True)

# Debugging: Check the results DataFrame before reindexing
print("Before reindexing results DataFrame:", results.columns)

# Ensure all dates are in the results DataFrame
results = results.set_index('Date').reindex(all_dates).reset_index()

# Handle NA values in 'Actual' and 'Forecast_signal' columns
results['Actual'] = results['Actual'].ffill()  # Forward fill for actual values
results['Forecast_signal'] = results['Forecast_signal'].fillna(0)  # Fill forecast NaNs with 0 or a placeholder value

# Final debug output before plotting
print("Final results DataFrame:", results.head())

# Create the interactive plot
fig = go.Figure()
fig.add_trace(go.Scatter(
    x=results['Date'],
    y=results['Actual'],
    mode='lines',
    name='Actual Values',
    line=dict(color='blue')
))

fig.add_trace(go.Scatter(
    x=results['Date'],
    y=results['Forecast_signal'],
    mode='lines',
    name='Forecasted Values',
    line=dict(color='red')
))

fig.update_layout(
    title="Forecasted vs Actual Signal Values (Next-Day Predictions)",
    xaxis_title="Date",
    yaxis_title="Signal Value",
    legend_title="Legend",
    hovermode="x unified"
)

fig.show()

# Save the results to a CSV file
results.to_csv('Chronos_Signal_pred.csv', index=False)
files.download('Chronos_Signal_pred.csv')
# Out:
# After reindexing Signal: Index(['Date', 'Signal'], dtype='object')
# Result DataFrame at iteration 872:
#         Date  Actual  Forecast_signal
# 0 2013-05-25     NaN         0.998738
# Result DataFrame at iteration 873:
#         Date  Actual  Forecast_signal
# 0 2013-05-26     NaN          0.99868
# Result DataFrame at iteration 874:
#         Date  Actual  Forecast_signal
# 0 2013-05-27     NaN     1.369044e-08
# Result DataFrame at iteration 875:
#         Date  Actual  Forecast_signal
# 0 2013-05-28     0.0          0.99868
# <ipython-input-24-b7daa42df9d3>:56: FutureWarning:
#
# The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
# Streaming output truncated to the last 5000 lines.
# 0 2020-02-09     NaN         1.003083
# Result DataFrame at iteration 3324:
#         Date  Actual  Forecast_signal
# 0 2020-02-10     1.0         1.003083
# Result DataFrame at iteration 3325:
#         Date  Actual  Forecast_signal
# 0 2020-02-11     1.0         1.003107
# Result DataFrame at iteration 3326:
#         Date  Actual  Forecast_signal
# 0 2020-02-12     1.0         1.003107
# Result DataFrame at iteration 3327:
#         Date  Actual  Forecast_signal
# 0 2020-02-13     1.0         1.003107
# Result DataFrame at iteration 3328:
#         Date  Actual  Forecast_signal
# 0 2020-02-14     1.0         1.003107
# Result DataFrame at iteration 3329:
#         Date  Actual  Forecast_signal
# 0 2020-02-15     NaN         1.003107
# Result DataFrame at iteration 3330:
#         Date  Actual  Forecast_signal
# 0 2020-02-16     NaN         1.003083
# Result DataFrame at iteration 3331:
#         Date  Actual  Forecast_signal
# 0 2020-02-17     NaN         1.003083
# Result DataFrame at iteration 3332:
#         Date  Actual  Forecast_signal
# 0 2020-02-18     1.0         1.003083
# Result DataFrame at iteration 3333:
#         Date  Actual  Forecast_signal
# 0 2020-02-19     1.0         1.003083
# Result DataFrame at iteration 3334:
#         Date  Actual  Forecast_signal
# 0 2020-02-20     1.0         1.003083
# Result DataFrame at iteration 3335:
#         Date  Actual  Forecast_signal
# 0 2020-02-21     1.0         1.003083
# Result DataFrame at iteration 3336:
#         Date  Actual  Forecast_signal
# 0 2020-02-22     NaN         1.003083
# Result DataFrame at iteration 3337:
#         Date  Actual  Forecast_signal
# 0 2020-02-23     NaN         1.003058
# Result DataFrame at iteration 3338:
#         Date  Actual  Forecast_signal
# 0 2020-02-24    -1.0         1.003058
# Result DataFrame at iteration 3339:
#         Date  Actual  Forecast_signal
# 0 2020-02-25    -1.0         1.003083
# Result DataFrame at iteration 3340:
#         Date  Actual  Forecast_signal
# 0 2020-02-26    -1.0         1.003083
# Result DataFrame at iteration 3341:
#         Date  Actual  Forecast_signal
# 0 2020-02-27     1.0         1.003083
# Result DataFrame at iteration 3342:
#         Date  Actual  Forecast_signal
# 0 2020-02-28     1.0         1.003083
# Result DataFrame at iteration 3343:
#         Date  Actual  Forecast_signal
# 0 2020-02-29     NaN         0.998676
# Result DataFrame at iteration 3344:
#         Date  Actual  Forecast_signal
# 0 2020-03-01     NaN        -1.013238
# Result DataFrame at iteration 3345:
#         Date  Actual  Forecast_signal
# 0 2020-03-02     1.0         1.005949
# Result DataFrame at iteration 3346:
#         Date  Actual  Forecast_signal
# 0 2020-03-03     1.0         0.998676
# Result DataFrame at iteration 3347:
#         Date  Actual  Forecast_signal
# 0 2020-03-04    -1.0        -0.998676
# Result DataFrame at iteration 3348:
#         Date  Actual  Forecast_signal
# 0 2020-03-05     1.0        -0.998676
# Result DataFrame at iteration 3349:
#         Date  Actual  Forecast_signal
# 0 2020-03-06     1.0        -0.984097
# Result DataFrame at iteration 3350:
#         Date  Actual  Forecast_signal
# 0 2020-03-07     NaN        -0.991386
# Result DataFrame at iteration 3351:
#         Date  Actual  Forecast_signal
# 0 2020-03-08     NaN         -0.99137
# Result DataFrame at iteration 3352:
#         Date  Actual  Forecast_signal
# 0 2020-03-09     1.0         0.998659
# Result DataFrame at iteration 3353:
#         Date  Actual  Forecast_signal
# 0 2020-03-10     1.0         0.998676
# Result DataFrame at iteration 3354:
#         Date  Actual  Forecast_signal
# 0 2020-03-11     1.0         0.998676
# Result DataFrame at iteration 3355:
#         Date  Actual  Forecast_signal
# 0 2020-03-12     1.0         0.998676
# Result DataFrame at iteration 3356:
#         Date  Actual  Forecast_signal
# 0 2020-03-13     1.0        -1.013255
# Result DataFrame at iteration 3357:
#         Date  Actual  Forecast_signal
# 0 2020-03-14     NaN         0.998676
# Result DataFrame at iteration 3358:
#         Date  Actual  Forecast_signal
# 0 2020-03-15     NaN         0.998659
# Result DataFrame at iteration 3359:
#         Date  Actual  Forecast_signal
# 0 2020-03-16     1.0        -0.998659
# Result DataFrame at iteration 3360:
#         Date  Actual  Forecast_signal
# 0 2020-03-17     1.0        -0.998676
# Result DataFrame at iteration 3361:
#         Date  Actual  Forecast_signal
# 0 2020-03-18     1.0         0.998676
# Result DataFrame at iteration 3362:
#         Date  Actual  Forecast_signal
# 0 2020-03-19     1.0         0.998676
# Result DataFrame at iteration 3363:
#         Date  Actual  Forecast_signal
# 0 2020-03-20     1.0         0.998676
# Result DataFrame at iteration 3364:
#         Date  Actual  Forecast_signal
# 0 2020-03-21     NaN         0.998676
# Result DataFrame at iteration 3365:
#         Date  Actual  Forecast_signal
# 0 2020-03-22     NaN        -0.998659
# Result DataFrame at iteration 3366:
#         Date  Actual  Forecast_signal
# 0 2020-03-23     1.0         0.998659
# Result DataFrame at iteration 3367:
#         Date  Actual  Forecast_signal
# 0 2020-03-24     1.0        -0.991386
# Result DataFrame at iteration 3368:
#         Date  Actual  Forecast_signal
# 0 2020-03-25     1.0         0.998676
# Result DataFrame at iteration 3369:
#         Date  Actual  Forecast_signal
# 0 2020-03-26     1.0         0.998676
# Result DataFrame at iteration 3370:
#         Date  Actual  Forecast_signal
# 0 2020-03-27     1.0         0.998676
# Result DataFrame at iteration 3371:
#         Date  Actual  Forecast_signal
# 0 2020-03-28     NaN         0.998676
# Result DataFrame at iteration 3372:
#         Date  Actual  Forecast_signal
# 0 2020-03-29     NaN        -1.005949
# Result DataFrame at iteration 3373:
#         Date  Actual  Forecast_signal
# 0 2020-03-30     1.0         0.998659
# Result DataFrame at iteration 3374:
#         Date  Actual  Forecast_signal
# 0 2020-03-31     1.0         0.998676
# Result DataFrame at iteration 3375:
#         Date  Actual  Forecast_signal
# 0 2020-04-01     1.0         0.998676
# Result DataFrame at iteration 3376:
#         Date  Actual  Forecast_signal
# 0 2020-04-02     1.0         0.998676
# Result DataFrame at iteration 3377:
#         Date  Actual  Forecast_signal
# 0 2020-04-03     1.0         0.998676
# Result DataFrame at iteration 3378:
#         Date  Actual  Forecast_signal
# 0 2020-04-04     NaN         0.998676
# Result DataFrame at iteration 3379:
#         Date  Actual  Forecast_signal
# 0 2020-04-05     NaN     1.389001e-08
# Result DataFrame at iteration 3380:
#         Date  Actual  Forecast_signal
# 0 2020-04-06     1.0         0.998659
# Result DataFrame at iteration 3381:
#         Date  Actual  Forecast_signal
# 0 2020-04-07     1.0         0.998676
# Result DataFrame at iteration 3382:
#         Date  Actual  Forecast_signal
# 0 2020-04-08     1.0         0.998676
# Result DataFrame at iteration 3383:
#         Date  Actual  Forecast_signal
# 0 2020-04-09     1.0         0.998676
# Result DataFrame at iteration 3384:
#         Date  Actual  Forecast_signal
# 0 2020-04-10     NaN         0.998676
# Result DataFrame at iteration 3385:
#         Date  Actual  Forecast_signal
# 0 2020-04-11     NaN         0.998659
# Result DataFrame at iteration 3386:
#         Date  Actual  Forecast_signal
# 0 2020-04-12     NaN         0.998643
# Result DataFrame at iteration 3387:
#         Date  Actual  Forecast_signal
# 0 2020-04-13     1.0        -0.991354
# Result DataFrame at iteration 3388:
#         Date  Actual  Forecast_signal
# 0 2020-04-14    -1.0         0.998659
# Result DataFrame at iteration 3389:
#         Date  Actual  Forecast_signal
# 0 2020-04-15     1.0         -0.99137
# Result DataFrame at iteration 3390:
#         Date  Actual  Forecast_signal
# 0 2020-04-16     1.0         0.998659
# Result DataFrame at iteration 3391:
#         Date  Actual  Forecast_signal
# 0 2020-04-17     1.0         0.998659
# Result DataFrame at iteration 3392:
#         Date  Actual  Forecast_signal
# 0 2020-04-18     NaN         0.998676
# Result DataFrame at iteration 3393:
#         Date  Actual  Forecast_signal
# 0 2020-04-19     NaN         0.998659
# Result DataFrame at iteration 3394:
#         Date  Actual  Forecast_signal
# 0 2020-04-20     1.0        -0.998659
# Result DataFrame at iteration 3395:
#         Date  Actual  Forecast_signal
# 0 2020-04-21     1.0        -1.005965
# Result DataFrame at iteration 3396:
#         Date  Actual  Forecast_signal
# 0 2020-04-22     1.0         1.001537
# Result DataFrame at iteration 3397:
#         Date  Actual  Forecast_signal
# 0 2020-04-23     1.0         1.001537
# Result DataFrame at iteration 3398:
#         Date  Actual  Forecast_signal
# 0 2020-04-24     1.0         1.001537
# Result DataFrame at iteration 3399:
#         Date  Actual  Forecast_signal
# 0 2020-04-25     NaN         1.001537
# Result DataFrame at iteration 3400:
#         Date  Actual  Forecast_signal
# 0 2020-04-26     NaN         1.001529
# Result DataFrame at iteration 3401:
#         Date  Actual  Forecast_signal
# 0 2020-04-27     1.0         1.001529
# Result DataFrame at iteration 3402:
#         Date  Actual  Forecast_signal
# 0 2020-04-28     1.0         1.001537
# Result DataFrame at iteration 3403:
#         Date  Actual  Forecast_signal
# 0 2020-04-29     1.0         1.001537
# Result DataFrame at iteration 3404:
#         Date  Actual  Forecast_signal
# 0 2020-04-30     1.0         1.001537
# Result DataFrame at iteration 3405:
#         Date  Actual  Forecast_signal
# 0 2020-05-01     1.0         1.001545
# Result DataFrame at iteration 3406:
#         Date  Actual  Forecast_signal
# 0 2020-05-02     NaN         1.001545
# Result DataFrame at iteration 3407:
#         Date  Actual  Forecast_signal
# 0 2020-05-03     NaN        -0.994227
# Result DataFrame at iteration 3408:
#         Date  Actual  Forecast_signal
# 0 2020-05-04     1.0         1.001537
# Result DataFrame at iteration 3409:
#         Date  Actual  Forecast_signal
# 0 2020-05-05     1.0         1.001545
# Result DataFrame at iteration 3410:
#         Date  Actual  Forecast_signal
# 0 2020-05-06     1.0         1.001545
# Result DataFrame at iteration 3411:
#         Date  Actual  Forecast_signal
# 0 2020-05-07     1.0         1.001545
# Result DataFrame at iteration 3412:
#         Date  Actual  Forecast_signal
# 0 2020-05-08     1.0         1.001545
# Result DataFrame at iteration 3413:
#         Date  Actual  Forecast_signal
# 0 2020-05-09     NaN         1.001545
# Result DataFrame at iteration 3414:
#         Date  Actual  Forecast_signal
# 0 2020-05-10     NaN         1.001537
# Result DataFrame at iteration 3415:
#         Date  Actual  Forecast_signal
# 0 2020-05-11     1.0         1.001537
# Result DataFrame at iteration 3416:
#         Date  Actual  Forecast_signal
# 0 2020-05-12     1.0         1.001545
# Result DataFrame at iteration 3417:
#         Date  Actual  Forecast_signal
# 0 2020-05-13     1.0        -1.008856
# Result DataFrame at iteration 3418:
#         Date  Actual  Forecast_signal
# 0 2020-05-14     1.0         1.001545
# Result DataFrame at iteration 3419:
#         Date  Actual  Forecast_signal
# 0 2020-05-15     1.0         1.001545
# Result DataFrame at iteration 3420:
#         Date  Actual  Forecast_signal
# 0 2020-05-16     NaN         1.001545
# Result DataFrame at iteration 3421:
#         Date  Actual  Forecast_signal
# 0 2020-05-17     NaN         1.001537
# Result DataFrame at iteration 3422:
#         Date  Actual  Forecast_signal
# 0 2020-05-18     1.0        -1.008848
# Result DataFrame at iteration 3423:
#         Date  Actual  Forecast_signal
# 0 2020-05-19     1.0         1.001545
# Result DataFrame at iteration 3424:
#         Date  Actual  Forecast_signal
# 0 2020-05-20     1.0         1.001545
# Result DataFrame at iteration 3425:
#         Date  Actual  Forecast_signal
# 0 2020-05-21     1.0         1.001553
# Result DataFrame at iteration 3426:
#         Date  Actual  Forecast_signal
# 0 2020-05-22     1.0         1.001553
# Result DataFrame at iteration 3427:
#         Date  Actual  Forecast_signal
# 0 2020-05-23     NaN         1.001553
# Result DataFrame at iteration 3428:
#         Date  Actual  Forecast_signal
# 0 2020-05-24     NaN         1.001545
# Result DataFrame at iteration 3429:
#         Date  Actual  Forecast_signal
# 0 2020-05-25     NaN         1.001545
# Result DataFrame at iteration 3430:
#         Date  Actual  Forecast_signal
# 0 2020-05-26     1.0        -0.994235
# Result DataFrame at iteration 3431:
#         Date  Actual  Forecast_signal
# 0 2020-05-27     1.0         1.001545
# Result DataFrame at iteration 3432:
#         Date  Actual  Forecast_signal
# 0 2020-05-28     1.0         1.001553
# Result DataFrame at iteration 3433:
#         Date  Actual  Forecast_signal
# 0 2020-05-29     1.0        -1.008864
# Result DataFrame at iteration 3434:
#         Date  Actual  Forecast_signal
# 0 2020-05-30     NaN         1.001553
# Result DataFrame at iteration 3435:
#         Date  Actual  Forecast_signal
# 0 2020-05-31     NaN         1.001545
# Result DataFrame at iteration 3436:
#         Date  Actual  Forecast_signal
# 0 2020-06-01     1.0         1.001545
# Result DataFrame at iteration 3437:
#         Date  Actual  Forecast_signal
# 0 2020-06-02     1.0         1.001553
# Result DataFrame at iteration 3438:
#         Date  Actual  Forecast_signal
# 0 2020-06-03     1.0         1.001553
# Result DataFrame at iteration 3439:
#         Date  Actual  Forecast_signal
# 0 2020-06-04     1.0         1.001553
# Result DataFrame at iteration 3440:
#         Date  Actual  Forecast_signal
# 0 2020-06-05     1.0         1.001553
# Result DataFrame at iteration 3441:
#         Date  Actual  Forecast_signal
# 0 2020-06-06     NaN         1.001553
# Result DataFrame at iteration 3442:
#         Date  Actual  Forecast_signal
# 0 2020-06-07     NaN        -1.016166
# Result DataFrame at iteration 3443:
#         Date  Actual  Forecast_signal
# 0 2020-06-08     1.0         1.001545
# Result DataFrame at iteration 3444:
#         Date  Actual  Forecast_signal
# 0 2020-06-09     1.0         1.001553
# Result DataFrame at iteration 3445:
#         Date  Actual  Forecast_signal
# 0 2020-06-10     1.0         1.001553
# Result DataFrame at iteration 3446:
#         Date  Actual  Forecast_signal
# 0 2020-06-11     1.0         1.001553
# Result DataFrame at iteration 3447:
#         Date  Actual  Forecast_signal
# 0 2020-06-12     1.0         1.001553
# Result DataFrame at iteration 3448:
#         Date  Actual  Forecast_signal
# 0 2020-06-13     NaN         1.001553
# Result DataFrame at iteration 3449:
#         Date  Actual  Forecast_signal
# 0 2020-06-14     NaN         1.001545
# Result DataFrame at iteration 3450:
#         Date  Actual  Forecast_signal
# 0 2020-06-15     0.0         1.001545
# Result DataFrame at iteration 3451:
#         Date  Actual  Forecast_signal
# 0 2020-06-16     0.0        -0.575897
# Result DataFrame at iteration 3452:
#         Date  Actual  Forecast_signal
# 0 2020-06-17     1.0     1.385145e-08
# Result DataFrame at iteration 3453:
#         Date  Actual  Forecast_signal
# 0 2020-06-18     1.0         1.003156
# Result DataFrame at iteration 3454:
#         Date  Actual  Forecast_signal
# 0 2020-06-19     1.0         1.003156
# Result DataFrame at iteration 3455:
#         Date  Actual  Forecast_signal
# 0 2020-06-20     NaN         1.003156
# Result DataFrame at iteration 3456:
#         Date  Actual  Forecast_signal
# 0 2020-06-21     NaN         1.003132
# Result DataFrame at iteration 3457:
#         Date  Actual  Forecast_signal
# 0 2020-06-22     1.0         0.501566
# Result DataFrame at iteration 3458:
#         Date  Actual  Forecast_signal
# 0 2020-06-23     1.0         1.003156
# Result DataFrame at iteration 3459:
#         Date  Actual  Forecast_signal
# 0 2020-06-24     1.0         1.003156
# Result DataFrame at iteration 3460:
#         Date  Actual  Forecast_signal
# 0 2020-06-25     1.0         1.003156
# Result DataFrame at iteration 3461:
#         Date  Actual  Forecast_signal
# 0 2020-06-26     1.0         1.003156
# Result DataFrame at iteration 3462:
#         Date  Actual  Forecast_signal
# 0 2020-06-27     NaN         1.003156
# Result DataFrame at iteration 3463:
#         Date  Actual  Forecast_signal
# 0 2020-06-28     NaN         1.003132
# Result DataFrame at iteration 3464:
#         Date  Actual  Forecast_signal
# 0 2020-06-29     1.0         1.003132
# Result DataFrame at iteration 3465:
#         Date  Actual  Forecast_signal
# 0 2020-06-30     1.0         1.003156
# Result DataFrame at iteration 3466:
#         Date  Actual  Forecast_signal
# 0 2020-07-01     1.0         1.003156
# Result DataFrame at iteration 3467:
#         Date  Actual  Forecast_signal
# 0 2020-07-02     1.0         1.003156
# Result DataFrame at iteration 3468:
#         Date  Actual  Forecast_signal
# 0 2020-07-03     NaN         1.003156
# Result DataFrame at iteration 3469:
#         Date  Actual  Forecast_signal
# 0 2020-07-04     NaN         1.003132
# Result DataFrame at iteration 3470:
#         Date  Actual  Forecast_signal
# 0 2020-07-05     NaN     1.385078e-08
# Result DataFrame at iteration 3471:
#         Date  Actual  Forecast_signal
# 0 2020-07-06     1.0         1.003107
# Result DataFrame at iteration 3472:
#         Date  Actual  Forecast_signal
# 0 2020-07-07     1.0         1.003132
# Result DataFrame at iteration 3473:
#         Date  Actual  Forecast_signal
# 0 2020-07-08     1.0         1.003132
# Result DataFrame at iteration 3474:
#         Date  Actual  Forecast_signal
# 0 2020-07-09     1.0         1.003132
# Result DataFrame at iteration 3475:
#         Date  Actual  Forecast_signal
# 0 2020-07-10     1.0         1.003132
# Result DataFrame at iteration 3476:
#         Date  Actual  Forecast_signal
# 0 2020-07-11     NaN         1.003132
# Result DataFrame at iteration 3477:
#         Date  Actual  Forecast_signal
# 0 2020-07-12     NaN         1.003107
# Result DataFrame at iteration 3478:
#         Date  Actual  Forecast_signal
# 0 2020-07-13     1.0         1.003107
# Result DataFrame at iteration 3479:
#         Date  Actual  Forecast_signal
# 0 2020-07-14     1.0         1.003132
# Result DataFrame at iteration 3480:
#         Date  Actual  Forecast_signal
# 0 2020-07-15     1.0         1.003156
# Result DataFrame at iteration 3481:
#         Date  Actual  Forecast_signal
# 0 2020-07-16     1.0         1.003156
# Result DataFrame at iteration 3482:
#         Date  Actual  Forecast_signal
# 0 2020-07-17     1.0         1.003156
# Result DataFrame at iteration 3483:
#         Date  Actual  Forecast_signal
# 0 2020-07-18     NaN         1.003156
# Result DataFrame at iteration 3484:
#         Date  Actual  Forecast_signal
# 0 2020-07-19     NaN         1.003132
# Result DataFrame at iteration 3485:
#         Date  Actual  Forecast_signal
# 0 2020-07-20     1.0         1.003132
# Result DataFrame at iteration 3486:
#         Date  Actual  Forecast_signal
# 0 2020-07-21     1.0         1.003156
# Result DataFrame at iteration 3487:
#         Date  Actual  Forecast_signal
# 0 2020-07-22     1.0         1.003156
# Result DataFrame at iteration 3488:
#         Date  Actual  Forecast_signal
# 0 2020-07-23     1.0         1.003156
# Result DataFrame at iteration 3489:
#         Date  Actual  Forecast_signal
# 0 2020-07-24     1.0         1.003156
# Result DataFrame at iteration 3490:
#         Date  Actual  Forecast_signal
# 0 2020-07-25     NaN         1.003156
# Result DataFrame at iteration 3491:
#         Date  Actual  Forecast_signal
# 0 2020-07-26     NaN         1.003132
# Result DataFrame at iteration 3492:
#         Date  Actual  Forecast_signal
# 0 2020-07-27     1.0         1.003132
# Result DataFrame at iteration 3493:
#         Date  Actual  Forecast_signal
# 0 2020-07-28     1.0         1.003156
# Result DataFrame at iteration 3494:
#         Date  Actual  Forecast_signal
# 0 2020-07-29     1.0         1.003156
# Result DataFrame at iteration 3495:
#         Date  Actual  Forecast_signal
# 0 2020-07-30     1.0         1.003156
# Result DataFrame at iteration 3496:
#         Date  Actual  Forecast_signal
# 0 2020-07-31     1.0         1.003156
# Result DataFrame at iteration 3497:
#         Date  Actual  Forecast_signal
# 0 2020-08-01     NaN         1.003156
# Result DataFrame at iteration 3498:
#         Date  Actual  Forecast_signal
# 0 2020-08-02     NaN         1.003132
# Result DataFrame at iteration 3499:
#         Date  Actual  Forecast_signal
# 0 2020-08-03     1.0         1.003132
# Result DataFrame at iteration 3500:
#         Date  Actual  Forecast_signal
# 0 2020-08-04     1.0         1.003156
# Result DataFrame at iteration 3501:
#         Date  Actual  Forecast_signal
# 0 2020-08-05     1.0         1.003156
# Result DataFrame at iteration 3502:
#         Date  Actual  Forecast_signal
# 0 2020-08-06     1.0         1.003156
# Result DataFrame at iteration 3503:
#         Date  Actual  Forecast_signal
# 0 2020-08-07     1.0         1.003156
# Result DataFrame at iteration 3504:
#         Date  Actual  Forecast_signal
# 0 2020-08-08     NaN         1.003156
# Result DataFrame at iteration 3505:
#         Date  Actual  Forecast_signal
# 0 2020-08-09     NaN         1.003132
# Result DataFrame at iteration 3506:
#         Date  Actual  Forecast_signal
# 0 2020-08-10     1.0         1.003132
# Result DataFrame at iteration 3507:
#         Date  Actual  Forecast_signal
# 0 2020-08-11     1.0         1.003156
# Result DataFrame at iteration 3508:
#         Date  Actual  Forecast_signal
# 0 2020-08-12     1.0         1.003156
# Result DataFrame at iteration 3509:
#         Date  Actual  Forecast_signal
# 0 2020-08-13     1.0         1.003156
# Result DataFrame at iteration 3510:
#         Date  Actual  Forecast_signal
# 0 2020-08-14     1.0         1.003156
# Result DataFrame at iteration 3511:
#         Date  Actual  Forecast_signal
# 0 2020-08-15     NaN         1.003156
# Result DataFrame at iteration 3512:
#         Date  Actual  Forecast_signal
# 0 2020-08-16     NaN         1.003132
# Result DataFrame at iteration 3513:
#         Date  Actual  Forecast_signal
# 0 2020-08-17     1.0         1.003132
# Result DataFrame at iteration 3514:
#         Date  Actual  Forecast_signal
# 0 2020-08-18     1.0         1.003156
# Result DataFrame at iteration 3515:
#         Date  Actual  Forecast_signal
# 0 2020-08-19     1.0         1.003156
# Result DataFrame at iteration 3516:
#         Date  Actual  Forecast_signal
# 0 2020-08-20     1.0         1.003156
# Result DataFrame at iteration 3517:
#         Date  Actual  Forecast_signal
# 0 2020-08-21     1.0         1.003156
# Result DataFrame at iteration 3518:
#         Date  Actual  Forecast_signal
# 0 2020-08-22     NaN         1.003156
# Result DataFrame at iteration 3519:
#         Date  Actual  Forecast_signal
# 0 2020-08-23     NaN         1.003132
# Result DataFrame at iteration 3520:
#         Date  Actual  Forecast_signal
# 0 2020-08-24     1.0         1.003132
# Result DataFrame at iteration 3521:
#         Date  Actual  Forecast_signal
# 0 2020-08-25     1.0         1.003156
# Result DataFrame at iteration 3522:
#         Date  Actual  Forecast_signal
# 0 2020-08-26     1.0         1.003156
# Result DataFrame at iteration 3523:
#         Date  Actual  Forecast_signal
# 0 2020-08-27     1.0         1.003156
# Result DataFrame at iteration 3524:
#         Date  Actual  Forecast_signal
# 0 2020-08-28     1.0         1.003156
# Result DataFrame at iteration 3525:
#         Date  Actual  Forecast_signal
# 0 2020-08-29     NaN         1.003156
# Result DataFrame at iteration 3526:
#         Date  Actual  Forecast_signal
# 0 2020-08-30     NaN         1.003132
# Result DataFrame at iteration 3527:
#         Date  Actual  Forecast_signal
# 0 2020-08-31     1.0         1.003132
# Result DataFrame at iteration 3528:
#         Date  Actual  Forecast_signal
# 0 2020-09-01     1.0         1.003156
# Result DataFrame at iteration 3529:
#         Date  Actual  Forecast_signal
# 0 2020-09-02     1.0         1.003156
# Result DataFrame at iteration 3530:
#         Date  Actual  Forecast_signal
# 0 2020-09-03     1.0         1.003156
# Result DataFrame at iteration 3531:
#         Date  Actual  Forecast_signal
# 0 2020-09-04     1.0         1.003156
# Result DataFrame at iteration 3532:
#         Date  Actual  Forecast_signal
# 0 2020-09-05     NaN         1.003156
# Result DataFrame at iteration 3533:
#         Date  Actual  Forecast_signal
# 0 2020-09-06     NaN         1.003132
# Result DataFrame at iteration 3534:
#         Date  Actual  Forecast_signal
# 0 2020-09-07     NaN         1.003132
# Result DataFrame at iteration 3535:
#         Date  Actual  Forecast_signal
# 0 2020-09-08     0.0         1.003132
# Result DataFrame at iteration 3536:
#         Date  Actual  Forecast_signal
# 0 2020-09-09     1.0         1.000266
# Result DataFrame at iteration 3537:
#         Date  Actual  Forecast_signal
# 0 2020-09-10     1.0         1.000266
# Result DataFrame at iteration 3538:
#         Date  Actual  Forecast_signal
# 0 2020-09-11     1.0         1.000266
# Result DataFrame at iteration 3539:
#         Date  Actual  Forecast_signal
# 0 2020-09-12     NaN         1.000266
# Result DataFrame at iteration 3540:
#         Date  Actual  Forecast_signal
# 0 2020-09-13     NaN         1.000266
# Result DataFrame at iteration 3541:
#         Date  Actual  Forecast_signal
# 0 2020-09-14     1.0         1.000266
# Result DataFrame at iteration 3542:
#         Date  Actual  Forecast_signal
# 0 2020-09-15     1.0         1.000298
# Result DataFrame at iteration 3543:
#         Date  Actual  Forecast_signal
# 0 2020-09-16     1.0         1.000298
# Result DataFrame at iteration 3544:
#         Date  Actual  Forecast_signal
# 0 2020-09-17     1.0         1.000298
# Result DataFrame at iteration 3545:
#         Date  Actual  Forecast_signal
# 0 2020-09-18     1.0         1.000298
# Result DataFrame at iteration 3546:
#         Date  Actual  Forecast_signal
# 0 2020-09-19     NaN         1.000298
# Result DataFrame at iteration 3547:
#         Date  Actual  Forecast_signal
# 0 2020-09-20     NaN         1.000266
# Result DataFrame at iteration 3548:
#         Date  Actual  Forecast_signal
# 0 2020-09-21     1.0         1.000266
# Result DataFrame at iteration 3549:
#         Date  Actual  Forecast_signal
# 0 2020-09-22     1.0         1.000298
# Result DataFrame at iteration 3550:
#         Date  Actual  Forecast_signal
# 0 2020-09-23     1.0         1.000298
# Result DataFrame at iteration 3551:
#         Date  Actual  Forecast_signal
# 0 2020-09-24     1.0         1.000298
# Result DataFrame at iteration 3552:
#         Date  Actual  Forecast_signal
# 0 2020-09-25     1.0         1.000298
# Result DataFrame at iteration 3553:
#         Date  Actual  Forecast_signal
# 0 2020-09-26     NaN         1.000298
# Result DataFrame at iteration 3554:
#         Date  Actual  Forecast_signal
# 0 2020-09-27     NaN         1.000266
# Result DataFrame at iteration 3555:
#         Date  Actual  Forecast_signal
# 0 2020-09-28     1.0         1.000266
# Result DataFrame at iteration 3556:
#         Date  Actual  Forecast_signal
# 0 2020-09-29     1.0         1.000298
# Result DataFrame at iteration 3557:
#         Date  Actual  Forecast_signal
# 0 2020-09-30     1.0         1.000298
# Result DataFrame at iteration 3558:
#         Date  Actual  Forecast_signal
# 0 2020-10-01     1.0         1.000298
# Result DataFrame at iteration 3559:
#         Date  Actual  Forecast_signal
# 0 2020-10-02     1.0         1.000298
# Result DataFrame at iteration 3560:
#         Date  Actual  Forecast_signal
# 0 2020-10-03     NaN         1.000298
# Result DataFrame at iteration 3561:
#         Date  Actual  Forecast_signal
# 0 2020-10-04     NaN         1.000266
# Result DataFrame at iteration 3562:
#         Date  Actual  Forecast_signal
# 0 2020-10-05     1.0         1.000266
# Result DataFrame at iteration 3563:
#         Date  Actual  Forecast_signal
# 0 2020-10-06     1.0         1.000298
# Result DataFrame at iteration 3564:
#         Date  Actual  Forecast_signal
# 0 2020-10-07     1.0         1.000298
# Result DataFrame at iteration 3565:
#         Date  Actual  Forecast_signal
# 0 2020-10-08     1.0         1.000298
# Result DataFrame at iteration 3566:
#         Date  Actual  Forecast_signal
# 0 2020-10-09     1.0         1.000298
# Result DataFrame at iteration 3567:
#         Date  Actual  Forecast_signal
# 0 2020-10-10     NaN         1.000298
# Result DataFrame at iteration 3568:
#         Date  Actual  Forecast_signal
# 0 2020-10-11     NaN         1.000266
# Result DataFrame at iteration 3569:
#         Date  Actual  Forecast_signal
# 0 2020-10-12     1.0         1.000266
# Result DataFrame at iteration 3570:
#         Date  Actual  Forecast_signal
# 0 2020-10-13     1.0         1.000298
# Result DataFrame at iteration 3571:
#         Date  Actual  Forecast_signal
# 0 2020-10-14     1.0         1.000298
# Result DataFrame at iteration 3572:
#         Date  Actual  Forecast_signal
# 0 2020-10-15     1.0         1.000298
# Result DataFrame at iteration 3573:
#         Date  Actual  Forecast_signal
# 0 2020-10-16     1.0         1.000298
# Result DataFrame at iteration 3574:
#         Date  Actual  Forecast_signal
# 0 2020-10-17     NaN         1.000298
# Result DataFrame at iteration 3575:
#         Date  Actual  Forecast_signal
# 0 2020-10-18     NaN         1.000266
# Result DataFrame at iteration 3576:
#         Date  Actual  Forecast_signal
# 0 2020-10-19     1.0         1.000266
# Result DataFrame at iteration 3577:
#         Date  Actual  Forecast_signal
# 0 2020-10-20     1.0         1.000298
# Result DataFrame at iteration 3578:
#         Date  Actual  Forecast_signal
# 0 2020-10-21     1.0          1.00033
# Result DataFrame at iteration 3579:
#         Date  Actual  Forecast_signal
# 0 2020-10-22     1.0          1.00033
# Result DataFrame at iteration 3580:
#         Date  Actual  Forecast_signal
# 0 2020-10-23     1.0          1.00033
# Result DataFrame at iteration 3581:
#         Date  Actual  Forecast_signal
# 0 2020-10-24     NaN          1.00033
# Result DataFrame at iteration 3582:
#         Date  Actual  Forecast_signal
# 0 2020-10-25     NaN         1.000298
# Result DataFrame at iteration 3583:
#         Date  Actual  Forecast_signal
# 0 2020-10-26    -1.0         1.000298
# Result DataFrame at iteration 3584:
#         Date  Actual  Forecast_signal
# 0 2020-10-27    -1.0          1.00033
# Result DataFrame at iteration 3585:
#         Date  Actual  Forecast_signal
# 0 2020-10-28     1.0     1.381243e-08
# Result DataFrame at iteration 3586:
#         Date  Actual  Forecast_signal
# 0 2020-10-29     1.0     1.381243e-08
# Result DataFrame at iteration 3587:
#         Date  Actual  Forecast_signal
# 0 2020-10-30     1.0          1.00033
# Result DataFrame at iteration 3588:
#         Date  Actual  Forecast_signal
# 0 2020-10-31     NaN          1.00033
# Result DataFrame at iteration 3589:
#         Date  Actual  Forecast_signal
# 0 2020-11-01     NaN         1.000298
# Result DataFrame at iteration 3590:
#         Date  Actual  Forecast_signal
# 0 2020-11-02     1.0         1.000298
# Result DataFrame at iteration 3591:
#         Date  Actual  Forecast_signal
# 0 2020-11-03     1.0          1.00033
# Result DataFrame at iteration 3592:
#         Date  Actual  Forecast_signal
# 0 2020-11-04    -1.0          1.00033
# Result DataFrame at iteration 3593:
#         Date  Actual  Forecast_signal
# 0 2020-11-05     1.0         -1.00033
# Result DataFrame at iteration 3594:
#         Date  Actual  Forecast_signal
# 0 2020-11-06     1.0          1.00033
# Result DataFrame at iteration 3595:
#         Date  Actual  Forecast_signal
# 0 2020-11-07     NaN          1.00033
# Result DataFrame at iteration 3596:
#         Date  Actual  Forecast_signal
# 0 2020-11-08     NaN         1.000298
# Result DataFrame at iteration 3597:
#         Date  Actual  Forecast_signal
# 0 2020-11-09     1.0         1.000298
# Result DataFrame at iteration 3598:
#         Date  Actual  Forecast_signal
# 0 2020-11-10     1.0          1.00033
# Result DataFrame at iteration 3599:
#         Date  Actual  Forecast_signal
# 0 2020-11-11     1.0          1.00033
# Result DataFrame at iteration 3600:
#         Date  Actual  Forecast_signal
# 0 2020-11-12     1.0          1.00033
# Result DataFrame at iteration 3601:
#         Date  Actual  Forecast_signal
# 0 2020-11-13     1.0          1.00033
# Result DataFrame at iteration 3602:
#         Date  Actual  Forecast_signal
# 0 2020-11-14     NaN          1.00033
# Result DataFrame at iteration 3603:
#         Date  Actual  Forecast_signal
# 0 2020-11-15     NaN         1.000298
# Result DataFrame at iteration 3604:
#         Date  Actual  Forecast_signal
# 0 2020-11-16     1.0         1.000298
# Result DataFrame at iteration 3605:
#         Date  Actual  Forecast_signal
# 0 2020-11-17     1.0          1.00033
# Result DataFrame at iteration 3606:
#         Date  Actual  Forecast_signal
# 0 2020-11-18     1.0          1.00033
# Result DataFrame at iteration 3607:
#         Date  Actual  Forecast_signal
# 0 2020-11-19     1.0          1.00033
# Result DataFrame at iteration 3608:
#         Date  Actual  Forecast_signal
# 0 2020-11-20     1.0          1.00033
# Result DataFrame at iteration 3609:
#         Date  Actual  Forecast_signal
# 0 2020-11-21     NaN          1.00033
# Result DataFrame at iteration 3610:
#         Date  Actual  Forecast_signal
# 0 2020-11-22     NaN         1.000298
# Result DataFrame at iteration 3611:
#         Date  Actual  Forecast_signal
# 0 2020-11-23     1.0         1.000298
# Result DataFrame at iteration 3612:
#         Date  Actual  Forecast_signal
# 0 2020-11-24     1.0          1.00033
# Result DataFrame at iteration 3613:
#         Date  Actual  Forecast_signal
# 0 2020-11-25     1.0          1.00033
# Result DataFrame at iteration 3614:
#         Date  Actual  Forecast_signal
# 0 2020-11-26     NaN          1.00033
# Result DataFrame at iteration 3615:
#         Date  Actual  Forecast_signal
# 0 2020-11-27     1.0         1.000298
# Result DataFrame at iteration 3616:
#         Date  Actual  Forecast_signal
# 0 2020-11-28     NaN          1.00033
# Result DataFrame at iteration 3617:
#         Date  Actual  Forecast_signal
# 0 2020-11-29     NaN         1.000298
# Result DataFrame at iteration 3618:
#         Date  Actual  Forecast_signal
# 0 2020-11-30     1.0         1.000298
# Result DataFrame at iteration 3619:
#         Date  Actual  Forecast_signal
# 0 2020-12-01     1.0          1.00033
# Result DataFrame at iteration 3620:
#         Date  Actual  Forecast_signal
# 0 2020-12-02     1.0          1.00033
# Result DataFrame at iteration 3621:
#         Date  Actual  Forecast_signal
# 0 2020-12-03     1.0          1.00033
# Result DataFrame at iteration 3622:
#         Date  Actual  Forecast_signal
# 0 2020-12-04     1.0          1.00033
# Result DataFrame at iteration 3623:
#         Date  Actual  Forecast_signal
# 0 2020-12-05     NaN          1.00033
# Result DataFrame at iteration 3624:
#         Date  Actual  Forecast_signal
# 0 2020-12-06     NaN         1.000298
# Result DataFrame at iteration 3625:
#         Date  Actual  Forecast_signal
# 0 2020-12-07     1.0         1.000298
# Result DataFrame at iteration 3626:
#         Date  Actual  Forecast_signal
# 0 2020-12-08     1.0          1.00033
# Result DataFrame at iteration 3627:
#         Date  Actual  Forecast_signal
# 0 2020-12-09     1.0          1.00033
# Result DataFrame at iteration 3628:
#         Date  Actual  Forecast_signal
# 0 2020-12-10     1.0          1.00033
# Result DataFrame at iteration 3629:
#         Date  Actual  Forecast_signal
# 0 2020-12-11     1.0          1.00033
# Result DataFrame at iteration 3630:
#         Date  Actual  Forecast_signal
# 0 2020-12-12     NaN          1.00033
# Result DataFrame at iteration 3631:
#         Date  Actual  Forecast_signal
# 0 2020-12-13     NaN         1.000298
# Result DataFrame at iteration 3632:
#         Date  Actual  Forecast_signal
# 0 2020-12-14     1.0         1.000298
# Result DataFrame at iteration 3633:
#         Date  Actual  Forecast_signal
# 0 2020-12-15     1.0          1.00033
# Result DataFrame at iteration 3634:
#         Date  Actual  Forecast_signal
# 0 2020-12-16     1.0          1.00033
# Result DataFrame at iteration 3635:
#         Date  Actual  Forecast_signal
# 0 2020-12-17     1.0          1.00033
# Result DataFrame at iteration 3636:
#         Date  Actual  Forecast_signal
# 0 2020-12-18     1.0          1.00033
# Result DataFrame at iteration 3637:
#         Date  Actual  Forecast_signal
# 0 2020-12-19     NaN          1.00033
# Result DataFrame at iteration 3638:
#         Date  Actual  Forecast_signal
# 0 2020-12-20     NaN         1.000298
# Result DataFrame at iteration 3639:
#         Date  Actual  Forecast_signal
# 0 2020-12-21     1.0         1.000298
# Result DataFrame at iteration 3640:
#         Date  Actual  Forecast_signal
# 0 2020-12-22     1.0          1.00033
# Result DataFrame at iteration 3641:
#         Date  Actual  Forecast_signal
# 0 2020-12-23     1.0          1.00033
# Result DataFrame at iteration 3642:
#         Date  Actual  Forecast_signal
# 0 2020-12-24     1.0          1.00033
# Result DataFrame at iteration 3643:
#         Date  Actual  Forecast_signal
# 0 2020-12-25     NaN          1.00033
# Result DataFrame at iteration 3644:
#         Date  Actual  Forecast_signal
# 0 2020-12-26     NaN         1.000298
# Result DataFrame at iteration 3645:
#         Date  Actual  Forecast_signal
# 0 2020-12-27     NaN         1.000266
# Result DataFrame at iteration 3646:
#         Date  Actual  Forecast_signal
# 0 2020-12-28     1.0         1.000266
# Result DataFrame at iteration 3647:
#         Date  Actual  Forecast_signal
# 0 2020-12-29     1.0         1.000298
# Result DataFrame at iteration 3648:
#         Date  Actual  Forecast_signal
# 0 2020-12-30     1.0         1.000298
# Result DataFrame at iteration 3649:
#         Date  Actual  Forecast_signal
# 0 2020-12-31     1.0         1.000298
# Result DataFrame at iteration 3650:
#         Date  Actual  Forecast_signal
# 0 2021-01-01     NaN         1.000298
# Result DataFrame at iteration 3651:
#         Date  Actual  Forecast_signal
# 0 2021-01-02     NaN         1.000266
# Result DataFrame at iteration 3652:
#         Date  Actual  Forecast_signal
# 0 2021-01-03     NaN         1.000233
# Result DataFrame at iteration 3653:
#         Date  Actual  Forecast_signal
# 0 2021-01-04     1.0         1.000233
# Result DataFrame at iteration 3654:
#         Date  Actual  Forecast_signal
# 0 2021-01-05     1.0         1.000266
# Result DataFrame at iteration 3655:
#         Date  Actual  Forecast_signal
# 0 2021-01-06     1.0         1.000266
# Result DataFrame at iteration 3656:
#         Date  Actual  Forecast_signal
# 0 2021-01-07     1.0         1.000266
# Result DataFrame at iteration 3657:
#         Date  Actual  Forecast_signal
# 0 2021-01-08     1.0         1.000266
# Result DataFrame at iteration 3658:
#         Date  Actual  Forecast_signal
# 0 2021-01-09     NaN         1.000266
# Result DataFrame at iteration 3659:
#         Date  Actual  Forecast_signal
# 0 2021-01-10     NaN         1.000233
# Result DataFrame at iteration 3660:
#         Date  Actual  Forecast_signal
# 0 2021-01-11     1.0         1.000233
# Result DataFrame at iteration 3661:
#         Date  Actual  Forecast_signal
# 0 2021-01-12     1.0         1.000266
# Result DataFrame at iteration 3662:
#         Date  Actual  Forecast_signal
# 0 2021-01-13     1.0         1.000266
# Result DataFrame at iteration 3663:
#         Date  Actual  Forecast_signal
# 0 2021-01-14     1.0         1.000266
# Result DataFrame at iteration 3664:
#         Date  Actual  Forecast_signal
# 0 2021-01-15     1.0         1.000266
# Result DataFrame at iteration 3665:
#         Date  Actual  Forecast_signal
# 0 2021-01-16     NaN         1.000266
# Result DataFrame at iteration 3666:
#         Date  Actual  Forecast_signal
# 0 2021-01-17     NaN         1.000233
# Result DataFrame at iteration 3667:
#         Date  Actual  Forecast_signal
# 0 2021-01-18     NaN         1.000233
# Result DataFrame at iteration 3668:
#         Date  Actual  Forecast_signal
# 0 2021-01-19     1.0         1.000233
# Result DataFrame at iteration 3669:
#         Date  Actual  Forecast_signal
# 0 2021-01-20     1.0         1.000233
# Result DataFrame at iteration 3670:
#         Date  Actual  Forecast_signal
# 0 2021-01-21     1.0         1.000233
# Result DataFrame at iteration 3671:
#         Date  Actual  Forecast_signal
# 0 2021-01-22     1.0         1.000233
# Result DataFrame at iteration 3672:
#         Date  Actual  Forecast_signal
# 0 2021-01-23     NaN         1.000233
# Result DataFrame at iteration 3673:
#         Date  Actual  Forecast_signal
# 0 2021-01-24     NaN         1.000201
# Result DataFrame at iteration 3674:
#         Date  Actual  Forecast_signal
# 0 2021-01-25     1.0         1.000201
# Result DataFrame at iteration 3675:
#         Date  Actual  Forecast_signal
# 0 2021-01-26     1.0         1.000233
# Result DataFrame at iteration 3676:
#         Date  Actual  Forecast_signal
# 0 2021-01-27     1.0         1.000266
# Result DataFrame at iteration 3677:
#         Date  Actual  Forecast_signal
# 0 2021-01-28     1.0         1.000266
# Result DataFrame at iteration 3678:
#         Date  Actual  Forecast_signal
# 0 2021-01-29     1.0         1.000266
# Result DataFrame at iteration 3679:
#         Date  Actual  Forecast_signal
# 0 2021-01-30     NaN         1.000266
# Result DataFrame at iteration 3680:
#         Date  Actual  Forecast_signal
# 0 2021-01-31     NaN         1.000233
# Result DataFrame at iteration 3681:
#         Date  Actual  Forecast_signal
# 0 2021-02-01     1.0         1.000233
# Result DataFrame at iteration 3682:
#         Date  Actual  Forecast_signal
# 0 2021-02-02     1.0         1.000266
# Result DataFrame at iteration 3683:
#         Date  Actual  Forecast_signal
# 0 2021-02-03     1.0         1.000266
# Result DataFrame at iteration 3684:
#         Date  Actual  Forecast_signal
# 0 2021-02-04     1.0         1.000266
# Result DataFrame at iteration 3685:
#         Date  Actual  Forecast_signal
# 0 2021-02-05     1.0         1.000266
# Result DataFrame at iteration 3686:
#         Date  Actual  Forecast_signal
# 0 2021-02-06     NaN         1.000266
# Result DataFrame at iteration 3687:
#         Date  Actual  Forecast_signal
# 0 2021-02-07     NaN         1.000233
# Result DataFrame at iteration 3688:
#         Date  Actual  Forecast_signal
# 0 2021-02-08     1.0        -0.992985
# Result DataFrame at iteration 3689:
#         Date  Actual  Forecast_signal
# 0 2021-02-09     1.0         1.000266
# Result DataFrame at iteration 3690:
#         Date  Actual  Forecast_signal
# 0 2021-02-10     1.0         1.000266
# Result DataFrame at iteration 3691:
#         Date  Actual  Forecast_signal
# 0 2021-02-11     1.0         1.000266
# Result DataFrame at iteration 3692:
#         Date  Actual  Forecast_signal
# 0 2021-02-12     1.0         1.000266
# Result DataFrame at iteration 3693:
#         Date  Actual  Forecast_signal
# 0 2021-02-13     NaN         1.000266
# Result DataFrame at iteration 3694:
#         Date  Actual  Forecast_signal
# 0 2021-02-14     NaN         1.000233
# Result DataFrame at iteration 3695:
#         Date  Actual  Forecast_signal
# 0 2021-02-15     NaN         1.000233
# Result DataFrame at iteration 3696:
#         Date  Actual  Forecast_signal
# 0 2021-02-16     1.0         1.000233
# Result DataFrame at iteration 3697:
#         Date  Actual  Forecast_signal
# 0 2021-02-17     1.0         1.000233
# Result DataFrame at iteration 3698:
#         Date  Actual  Forecast_signal
# 0 2021-02-18     1.0         1.000233
# Result DataFrame at iteration 3699:
#         Date  Actual  Forecast_signal
# 0 2021-02-19     1.0         1.000233
# Result DataFrame at iteration 3700:
#         Date  Actual  Forecast_signal
# 0 2021-02-20     NaN         1.000233
# Result DataFrame at iteration 3701:
#         Date  Actual  Forecast_signal
# 0 2021-02-21     NaN         1.000201
# Result DataFrame at iteration 3702:
#         Date  Actual  Forecast_signal
# 0 2021-02-22     1.0         1.000201
# Result DataFrame at iteration 3703:
#         Date  Actual  Forecast_signal
# 0 2021-02-23     1.0         1.000233
# Result DataFrame at iteration 3704:
#         Date  Actual  Forecast_signal
# 0 2021-02-24     1.0         1.000233
# Result DataFrame at iteration 3705:
#         Date  Actual  Forecast_signal
# 0 2021-02-25     1.0         1.000233
# Result DataFrame at iteration 3706:
#         Date  Actual  Forecast_signal
# 0 2021-02-26     0.0         1.000233
# Result DataFrame at iteration 3707:
#         Date  Actual  Forecast_signal
# 0 2021-02-27     NaN         0.997359
# Result DataFrame at iteration 3708:
#         Date  Actual  Forecast_signal
# 0 2021-02-28     NaN         0.997318
# Result DataFrame at iteration 3709:
#         Date  Actual  Forecast_signal
# 0 2021-03-01     1.0         0.997318
# Result DataFrame at iteration 3710:
#         Date  Actual  Forecast_signal
# 0 2021-03-02     1.0         0.997359
# Result DataFrame at iteration 3711:
#         Date  Actual  Forecast_signal
# 0 2021-03-03     1.0         0.997359
# Result DataFrame at iteration 3712:
#         Date  Actual  Forecast_signal
# 0 2021-03-04     1.0         0.997359
# Result DataFrame at iteration 3713:
#         Date  Actual  Forecast_signal
# 0 2021-03-05     1.0         0.997359
# Result DataFrame at iteration 3714:
#         Date  Actual  Forecast_signal
# 0 2021-03-06     NaN         0.997359
# Result DataFrame at iteration 3715:
#         Date  Actual  Forecast_signal
# 0 2021-03-07     NaN         0.997318
# Result DataFrame at iteration 3716:
#         Date  Actual  Forecast_signal
# 0 2021-03-08     1.0         0.997318
# Result DataFrame at iteration 3717:
#         Date  Actual  Forecast_signal
# 0 2021-03-09     1.0         0.997359
# Result DataFrame at iteration 3718:
#         Date  Actual  Forecast_signal
# 0 2021-03-10     1.0         0.997359
# Result DataFrame at iteration 3719:
#         Date  Actual  Forecast_signal
# 0 2021-03-11     1.0         0.997359
# Result DataFrame at iteration 3720:
#         Date  Actual  Forecast_signal
# 0 2021-03-12     1.0         0.997359
# Result DataFrame at iteration 3721:
#         Date  Actual  Forecast_signal
# 0 2021-03-13     NaN         0.997359
# Result DataFrame at iteration 3722:
#         Date  Actual  Forecast_signal
# 0 2021-03-14     NaN         0.997318
# Result DataFrame at iteration 3723:
#         Date  Actual  Forecast_signal
# 0 2021-03-15     1.0         0.997318
# Result DataFrame at iteration 3724:
#         Date  Actual  Forecast_signal
# 0 2021-03-16     1.0         0.997359
# Result DataFrame at iteration 3725:
#         Date  Actual  Forecast_signal
# 0 2021-03-17     1.0         0.997359
# Result DataFrame at iteration 3726:
#         Date  Actual  Forecast_signal
# 0 2021-03-18     1.0         0.997359
# Result DataFrame at iteration 3727:
#         Date  Actual  Forecast_signal
# 0 2021-03-19     1.0         0.997359
# Result DataFrame at iteration 3728:
#         Date  Actual  Forecast_signal
# 0 2021-03-20     NaN         0.997359
# Result DataFrame at iteration 3729:
#         Date  Actual  Forecast_signal
# 0 2021-03-21     NaN         0.997318
# Result DataFrame at iteration 3730:
#         Date  Actual  Forecast_signal
# 0 2021-03-22     1.0         0.997318
# Result DataFrame at iteration 3731:
#         Date  Actual  Forecast_signal
# 0 2021-03-23     1.0         0.997359
# Result DataFrame at iteration 3732:
#         Date  Actual  Forecast_signal
# 0 2021-03-24     1.0         0.997359
# Result DataFrame at iteration 3733:
#         Date  Actual  Forecast_signal
# 0 2021-03-25     1.0         0.997359
# Result DataFrame at iteration 3734:
#         Date  Actual  Forecast_signal
# 0 2021-03-26     1.0         0.997359
# Result DataFrame at iteration 3735:
#         Date  Actual  Forecast_signal
# 0 2021-03-27     NaN         0.997359
# Result DataFrame at iteration 3736:
#         Date  Actual  Forecast_signal
# 0 2021-03-28     NaN         0.997318
# Result DataFrame at iteration 3737:
#         Date  Actual  Forecast_signal
# 0 2021-03-29     1.0         0.997318
# Result DataFrame at iteration 3738:
#         Date  Actual  Forecast_signal
# 0 2021-03-30     1.0         0.997359
# Result DataFrame at iteration 3739:
#         Date  Actual  Forecast_signal
# 0 2021-03-31     1.0         0.997359
# Result DataFrame at iteration 3740:
#         Date  Actual  Forecast_signal
# 0 2021-04-01     1.0         0.997359
# Result DataFrame at iteration 3741:
#         Date  Actual  Forecast_signal
# 0 2021-04-02     NaN         0.997359
# Result DataFrame at iteration 3742:
#         Date  Actual  Forecast_signal
# 0 2021-04-03     NaN         0.997318
# Result DataFrame at iteration 3743:
#         Date  Actual  Forecast_signal
# 0 2021-04-04     NaN         0.997277
# ...
# 0 2024-04-29     1.0         0.998282
# Result DataFrame at iteration 4865:
#         Date  Actual  Forecast_signal
# 0 2024-04-30     1.0         0.998383
# Result DataFrame at iteration 4866:
#         Date  Actual  Forecast_signal
# 0 2024-05-01     1.0         1.001328
# Result DataFrame at iteration 4867:
#         Date  Actual  Forecast_signal
# 0 2024-05-02     1.0         1.001328
# Result DataFrame at iteration 4868:
#         Date  Actual  Forecast_signal
# 0 2024-05-03     1.0         1.001328
# Result DataFrame at iteration 4869:
#         Date  Actual  Forecast_signal
# 0 2024-05-04     NaN         1.001328
# Result DataFrame at iteration 4870:
#         Date  Actual  Forecast_signal
# 0 2024-05-05     NaN         1.001236
# Result DataFrame at iteration 4871:
#         Date  Actual  Forecast_signal
# 0 2024-05-06     1.0     1.353079e-08
# Result DataFrame at iteration 4872:
#         Date  Actual  Forecast_signal
# 0 2024-05-07     1.0         1.001328
# Result DataFrame at iteration 4873:
#         Date  Actual  Forecast_signal
# 0 2024-05-08     1.0         1.001328
# Result DataFrame at iteration 4874:
#         Date  Actual  Forecast_signal
# 0 2024-05-09     1.0         0.997151
# Result DataFrame at iteration 4875:
#         Date  Actual  Forecast_signal
# 0 2024-05-10     1.0         0.997151
# Result DataFrame at iteration 4876:
#         Date  Actual  Forecast_signal
# 0 2024-05-11     NaN         0.997151
# Result DataFrame at iteration 4877:
#         Date  Actual  Forecast_signal
# 0 2024-05-12     NaN         0.997067
# Result DataFrame at iteration 4878:
#         Date  Actual  Forecast_signal
# 0 2024-05-13     1.0         0.997067
# Result DataFrame at iteration 4879:
#         Date  Actual  Forecast_signal
# 0 2024-05-14     1.0         0.997151
# Result DataFrame at iteration 4880:
#         Date  Actual  Forecast_signal
# 0 2024-05-15     1.0         0.997151
# Result DataFrame at iteration 4881:
#         Date  Actual  Forecast_signal
# 0 2024-05-16     1.0         0.997151
# Result DataFrame at iteration 4882:
#         Date  Actual  Forecast_signal
# 0 2024-05-17     1.0         0.997151
# Result DataFrame at iteration 4883:
#         Date  Actual  Forecast_signal
# 0 2024-05-18     NaN         0.997151
# Result DataFrame at iteration 4884:
#         Date  Actual  Forecast_signal
# 0 2024-05-19     NaN         0.997067
# Result DataFrame at iteration 4885:
#         Date  Actual  Forecast_signal
# 0 2024-05-20     1.0         0.997067
# Result DataFrame at iteration 4886:
#         Date  Actual  Forecast_signal
# 0 2024-05-21     1.0         0.997151
# Result DataFrame at iteration 4887:
#         Date  Actual  Forecast_signal
# 0 2024-05-22     1.0         0.997234
# Result DataFrame at iteration 4888:
#         Date  Actual  Forecast_signal
# 0 2024-05-23     1.0     1.357297e-08
# Result DataFrame at iteration 4889:
#         Date  Actual  Forecast_signal
# 0 2024-05-24     1.0         0.997234
# Result DataFrame at iteration 4890:
#         Date  Actual  Forecast_signal
# 0 2024-05-25     NaN         0.997234
# Result DataFrame at iteration 4891:
#         Date  Actual  Forecast_signal
# 0 2024-05-26     NaN         0.997151
# Result DataFrame at iteration 4892:
#         Date  Actual  Forecast_signal
# 0 2024-05-27     NaN         0.997151
# Result DataFrame at iteration 4893:
#         Date  Actual  Forecast_signal
# 0 2024-05-28     1.0         0.997151
# Result DataFrame at iteration 4894:
#         Date  Actual  Forecast_signal
# 0 2024-05-29     1.0         0.997234
# Result DataFrame at iteration 4895:
#         Date  Actual  Forecast_signal
# 0 2024-05-30     1.0         0.997234
# Result DataFrame at iteration 4896:
#         Date  Actual  Forecast_signal
# 0 2024-05-31     1.0         0.997234
# Result DataFrame at iteration 4897:
#         Date  Actual  Forecast_signal
# 0 2024-06-01     NaN         0.997234
# Result DataFrame at iteration 4898:
#         Date  Actual  Forecast_signal
# 0 2024-06-02     NaN         0.997151
# Result DataFrame at iteration 4899:
#         Date  Actual  Forecast_signal
# 0 2024-06-03     1.0         0.997151
# Result DataFrame at iteration 4900:
#         Date  Actual  Forecast_signal
# 0 2024-06-04     0.0         0.997234
# Result DataFrame at iteration 4901:
#         Date  Actual  Forecast_signal
# 0 2024-06-05     0.0     1.357297e-08
# Result DataFrame at iteration 4902:
#         Date  Actual  Forecast_signal
# 0 2024-06-06     1.0     1.353328e-08
# Result DataFrame at iteration 4903:
#         Date  Actual  Forecast_signal
# 0 2024-06-07     1.0         0.997234
# Result DataFrame at iteration 4904:
#         Date  Actual  Forecast_signal
# 0 2024-06-08     NaN     1.357297e-08
# Result DataFrame at iteration 4905:
#         Date  Actual  Forecast_signal
# 0 2024-06-09     NaN         0.997151
# Result DataFrame at iteration 4906:
#         Date  Actual  Forecast_signal
# 0 2024-06-10     1.0         0.997151
# Result DataFrame at iteration 4907:
#         Date  Actual  Forecast_signal
# 0 2024-06-11     1.0         0.997234
# Result DataFrame at iteration 4908:
#         Date  Actual  Forecast_signal
# 0 2024-06-12     1.0     1.357409e-08
# Result DataFrame at iteration 4909:
#         Date  Actual  Forecast_signal
# 0 2024-06-13     1.0         0.997317
# Result DataFrame at iteration 4910:
#         Date  Actual  Forecast_signal
# 0 2024-06-14     1.0         0.997317
# Result DataFrame at iteration 4911:
#         Date  Actual  Forecast_signal
# 0 2024-06-15     NaN     1.357409e-08
# Result DataFrame at iteration 4912:
#         Date  Actual  Forecast_signal
# 0 2024-06-16     NaN     1.357297e-08
# Result DataFrame at iteration 4913:
#         Date  Actual  Forecast_signal
# 0 2024-06-17     1.0         0.997234
# Result DataFrame at iteration 4914:
#         Date  Actual  Forecast_signal
# 0 2024-06-18     1.0         0.997317
# Result DataFrame at iteration 4915:
#         Date  Actual  Forecast_signal
# 0 2024-06-19     NaN         1.000224
# Result DataFrame at iteration 4916:
#         Date  Actual  Forecast_signal
# 0 2024-06-20     1.0          1.00015
# Result DataFrame at iteration 4917:
#         Date  Actual  Forecast_signal
# 0 2024-06-21     1.0          1.00015
# Result DataFrame at iteration 4918:
#         Date  Actual  Forecast_signal
# 0 2024-06-22     NaN          1.00015
# Result DataFrame at iteration 4919:
#         Date  Actual  Forecast_signal
# 0 2024-06-23     NaN         1.002999
# Result DataFrame at iteration 4920:
#         Date  Actual  Forecast_signal
# 0 2024-06-24     1.0     1.365144e-08
# Result DataFrame at iteration 4921:
#         Date  Actual  Forecast_signal
# 0 2024-06-25     1.0         1.003066
# Result DataFrame at iteration 4922:
#         Date  Actual  Forecast_signal
# 0 2024-06-26     1.0         1.003066
# Result DataFrame at iteration 4923:
#         Date  Actual  Forecast_signal
# 0 2024-06-27     1.0         1.003066
# Result DataFrame at iteration 4924:
#         Date  Actual  Forecast_signal
# 0 2024-06-28     1.0     1.365234e-08
# Result DataFrame at iteration 4925:
#         Date  Actual  Forecast_signal
# 0 2024-06-29     NaN         1.003066
# Result DataFrame at iteration 4926:
#         Date  Actual  Forecast_signal
# 0 2024-06-30     NaN         1.002999
# Result DataFrame at iteration 4927:
#         Date  Actual  Forecast_signal
# 0 2024-07-01     1.0         1.002999
# Result DataFrame at iteration 4928:
#         Date  Actual  Forecast_signal
# 0 2024-07-02     1.0         1.003066
# Result DataFrame at iteration 4929:
#         Date  Actual  Forecast_signal
# 0 2024-07-03     1.0         0.998796
# Result DataFrame at iteration 4930:
#         Date  Actual  Forecast_signal
# 0 2024-07-04     NaN         0.998796
# Result DataFrame at iteration 4931:
#         Date  Actual  Forecast_signal
# 0 2024-07-05     1.0         1.001642
# Result DataFrame at iteration 4932:
#         Date  Actual  Forecast_signal
# 0 2024-07-06     NaN         1.001642
# Result DataFrame at iteration 4933:
#         Date  Actual  Forecast_signal
# 0 2024-07-07     NaN     1.373036e-08
# Result DataFrame at iteration 4934:
#         Date  Actual  Forecast_signal
# 0 2024-07-08     1.0         2.003184
# Result DataFrame at iteration 4935:
#         Date  Actual  Forecast_signal
# 0 2024-07-09     1.0         1.001642
# Result DataFrame at iteration 4936:
#         Date  Actual  Forecast_signal
# 0 2024-07-10     1.0         0.997318
# Result DataFrame at iteration 4937:
#         Date  Actual  Forecast_signal
# 0 2024-07-11     1.0         0.997318
# Result DataFrame at iteration 4938:
#         Date  Actual  Forecast_signal
# 0 2024-07-12     1.0         0.997318
# Result DataFrame at iteration 4939:
#         Date  Actual  Forecast_signal
# 0 2024-07-13     NaN         0.997318
# Result DataFrame at iteration 4940:
#         Date  Actual  Forecast_signal
# 0 2024-07-14     NaN         0.997277
# Result DataFrame at iteration 4941:
#         Date  Actual  Forecast_signal
# 0 2024-07-15     1.0         0.997277
# Result DataFrame at iteration 4942:
#         Date  Actual  Forecast_signal
# 0 2024-07-16     1.0         0.997318
# Result DataFrame at iteration 4943:
#         Date  Actual  Forecast_signal
# 0 2024-07-17     1.0         0.997359
# Result DataFrame at iteration 4944:
#         Date  Actual  Forecast_signal
# 0 2024-07-18     1.0         0.997359
# Result DataFrame at iteration 4945:
#         Date  Actual  Forecast_signal
# 0 2024-07-19     1.0         0.997359
# Result DataFrame at iteration 4946:
#         Date  Actual  Forecast_signal
# 0 2024-07-20     NaN         0.997359
# Result DataFrame at iteration 4947:
#         Date  Actual  Forecast_signal
# 0 2024-07-21     NaN         0.997318
# Result DataFrame at iteration 4948:
#         Date  Actual  Forecast_signal
# 0 2024-07-22     1.0         0.997318
# Result DataFrame at iteration 4949:
#         Date  Actual  Forecast_signal
# 0 2024-07-23     1.0         0.997359
# Result DataFrame at iteration 4950:
#         Date  Actual  Forecast_signal
# 0 2024-07-24     1.0         0.997359
# Result DataFrame at iteration 4951:
#         Date  Actual  Forecast_signal
# 0 2024-07-25     1.0         0.997359
# Result DataFrame at iteration 4952:
#         Date  Actual  Forecast_signal
# 0 2024-07-26     1.0         0.997359
# Result DataFrame at iteration 4953:
#         Date  Actual  Forecast_signal
# 0 2024-07-27     NaN         0.997359
# Result DataFrame at iteration 4954:
#         Date  Actual  Forecast_signal
# 0 2024-07-28     NaN         0.997318
# Result DataFrame at iteration 4955:
#         Date  Actual  Forecast_signal
# 0 2024-07-29     1.0         0.997318
# Result DataFrame at iteration 4956:
#         Date  Actual  Forecast_signal
# 0 2024-07-30     1.0         0.997359
# Result DataFrame at iteration 4957:
#         Date  Actual  Forecast_signal
# 0 2024-07-31     1.0         0.997359
# Result DataFrame at iteration 4958:
#         Date  Actual  Forecast_signal
# 0 2024-08-01     1.0         0.997359
# Result DataFrame at iteration 4959:
#         Date  Actual  Forecast_signal
# 0 2024-08-02     1.0         0.997359
# Result DataFrame at iteration 4960:
#         Date  Actual  Forecast_signal
# 0 2024-08-03     NaN         0.997359
# Result DataFrame at iteration 4961:
#         Date  Actual  Forecast_signal
# 0 2024-08-04     NaN         0.997318
# Result DataFrame at iteration 4962:
#         Date  Actual  Forecast_signal
# 0 2024-08-05     1.0         0.997318
# Result DataFrame at iteration 4963:
#         Date  Actual  Forecast_signal
# 0 2024-08-06    -1.0         0.997359
# Result DataFrame at iteration 4964:
#         Date  Actual  Forecast_signal
# 0 2024-08-07    -1.0         0.997359
# Result DataFrame at iteration 4965:
#         Date  Actual  Forecast_signal
# 0 2024-08-08     1.0         0.997359
# Result DataFrame at iteration 4966:
#         Date  Actual  Forecast_signal
# 0 2024-08-09     1.0         0.997359
# Result DataFrame at iteration 4967:
#         Date  Actual  Forecast_signal
# 0 2024-08-10     NaN         0.997359
# Result DataFrame at iteration 4968:
#         Date  Actual  Forecast_signal
# 0 2024-08-11     NaN         1.000201
# Result DataFrame at iteration 4969:
#         Date  Actual  Forecast_signal
# 0 2024-08-12     1.0         1.000201
# Result DataFrame at iteration 4970:
#         Date  Actual  Forecast_signal
# 0 2024-08-13     1.0         1.000233
# Result DataFrame at iteration 4971:
#         Date  Actual  Forecast_signal
# 0 2024-08-14     1.0         1.000233
# Result DataFrame at iteration 4972:
#         Date  Actual  Forecast_signal
# 0 2024-08-15     1.0         1.003107
# Result DataFrame at iteration 4973:
#         Date  Actual  Forecast_signal
# 0 2024-08-16     1.0         0.998692
# Result DataFrame at iteration 4974:
#         Date  Actual  Forecast_signal
# 0 2024-08-17     NaN         0.998692
# Result DataFrame at iteration 4975:
#         Date  Actual  Forecast_signal
# 0 2024-08-18     NaN         0.998676
# Result DataFrame at iteration 4976:
#         Date  Actual  Forecast_signal
# 0 2024-08-19     1.0     1.389024e-08
# Result DataFrame at iteration 4977:
#         Date  Actual  Forecast_signal
# 0 2024-08-20     1.0         0.998692
# Result DataFrame at iteration 4978:
#         Date  Actual  Forecast_signal
# 0 2024-08-21     1.0         0.998692
# Result DataFrame at iteration 4979:
#         Date  Actual  Forecast_signal
# 0 2024-08-22     1.0        -1.013271
# Result DataFrame at iteration 4980:
#         Date  Actual  Forecast_signal
# 0 2024-08-23     1.0         0.998692
# Result DataFrame at iteration 4981:
#         Date  Actual  Forecast_signal
# 0 2024-08-24     NaN         0.998692
# Result DataFrame at iteration 4982:
#         Date  Actual  Forecast_signal
# 0 2024-08-25     NaN         0.998676
# Result DataFrame at iteration 4983:
#         Date  Actual  Forecast_signal
# 0 2024-08-26     1.0         0.998676
# Result DataFrame at iteration 4984:
#         Date  Actual  Forecast_signal
# 0 2024-08-27     1.0         0.998692
# Result DataFrame at iteration 4985:
#         Date  Actual  Forecast_signal
# 0 2024-08-28     1.0         0.998692
# Result DataFrame at iteration 4986:
#         Date  Actual  Forecast_signal
# 0 2024-08-29     1.0         0.998692
# Result DataFrame at iteration 4987:
#         Date  Actual  Forecast_signal
# 0 2024-08-30     1.0         0.998692
# Before reindexing results DataFrame: Index(['Date', 'Actual', 'Forecast_signal'], dtype='object')
# Final results DataFrame:                       index  Actual  Forecast_signal
# 0 2011-01-03 00:00:00+00:00     NaN              0.0
# 1 2011-01-04 00:00:00+00:00     NaN              0.0
# 2 2011-01-05 00:00:00+00:00     NaN              0.0
# 3 2011-01-06 00:00:00+00:00     NaN              0.0
# 4 2011-01-07 00:00:00+00:00     NaN              0.0
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3790         try:
# -> 3791             return self._engine.get_loc(casted_key)
#    3792         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-b7daa42df9d3> in <cell line: 76>()
#      75 fig = go.Figure()
#      76 fig.add_trace(go.Scatter(
# ---> 77     x=results['Date'],
#      78     y=results['Actual'],
#      79     mode='lines',
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3891             if self.columns.nlevels > 1:
#    3892                 return self._getitem_multilevel(key)
# -> 3893             indexer = self.columns.get_loc(key)
#    3894             if is_integer(indexer):
#    3895                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3796             ):
#    3797                 raise InvalidIndexError(key)
# -> 3798             raise KeyError(key) from err
#    3799         except TypeError:
#    3800             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'Date'

# %%
results
# Out:
#                          index  Actual  Forecast_signal
# 0    2011-01-03 00:00:00+00:00     NaN              0.0
# 1    2011-01-04 00:00:00+00:00     NaN              0.0
# 2    2011-01-05 00:00:00+00:00     NaN              0.0
# 3    2011-01-06 00:00:00+00:00     NaN              0.0
# 4    2011-01-07 00:00:00+00:00     NaN              0.0
# ...                        ...     ...              ...
# 4984 2024-08-26 00:00:00+00:00     NaN              0.0
# 4985 2024-08-27 00:00:00+00:00     NaN              0.0
# 4986 2024-08-28 00:00:00+00:00     NaN              0.0
# 4987 2024-08-29 00:00:00+00:00     NaN              0.0
# 4988 2024-08-30 00:00:00+00:00     NaN              0.0
#
# [4989 rows x 3 columns]
